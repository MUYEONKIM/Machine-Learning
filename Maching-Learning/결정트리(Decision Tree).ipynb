# %% [markdown]
# # 결정 트리(Decision Tree)
#
# * 분류와 회귀에 사용되는 지도 학습 방법
# * 데이터 특성으로 부터 추론된 결정 규칙을 통해 값을 예측
# * **if-then-else** 결정 규칙을 통해 데이터 학습
# * 트리의 깊이가 깊을 수록 복잡한 모델
# * 결정 트리 장점
#   * 이해와 해석이 쉽다 (선택한 이유를 알 수 있기 때문에)
#   * 시각화가 용이하다
#   * 많은 데이터 전처리가 필요하지 않다
#   * 수치형과 범주형 데이터 모두를 다룰 수 있다
#   * ...

# %%
import pandas as pd
import numpy as np
import graphviz
import multiprocessing
import matplotlib.pyplot as plt
plt.style.use(['seaborn-whitegrid'])

# %%
from sklearn.datasets import load_iris, load_wine, load_breast_cancer
from sklearn.datasets import load_boston, load_diabetes
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline

# %% [markdown]
# ## 분류를 위한 데이터

# %% [markdown]
# ### 붓꽃 데이터

# %%
iris = load_iris()

# %%
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 와인 데이터

# %%
wine = load_wine()

# %%
wine_df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
wine_df['target'] = wine.target
wine_df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline  target
# 0                            3.92   1065.0       0
# 1                            3.40   1050.0       0
# 2                            3.17   1185.0       0
# 3                            3.45   1480.0       0
# 4                            2.93    735.0       0
# ..                            ...      ...     ...
# 173                          1.74    740.0       2
# 174                          1.56    750.0       2
# 175                          1.56    835.0       2
# 176                          1.62    840.0       2
# 177                          1.60    560.0       2
#
# [178 rows x 14 columns]

# %% [markdown]
# ### 유방암 데이터

# %%
cancer = load_breast_cancer()

# %%
cancer_df = pd.DataFrame(data = cancer.data, columns= cancer.feature_names)
cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 회귀를 위한 데이터

# %% [markdown]
# ### 보스턴 주택 가격 데이터

# %%
boston = load_boston()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
boston_df = pd.DataFrame(data=boston.data, columns=boston.feature_names)
boston_df['target'] = boston.target
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# ### 당뇨병 데이터

# %%
diabetes = load_diabetes()

# %%
diabates_df = pd.DataFrame(data = diabetes.data , columns=diabetes.feature_names)
diabates_df['target'] = diabetes.target
diabates_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019908 -0.017646   151.0
# 1 -0.039493 -0.068330 -0.092204    75.0
# 2 -0.002592  0.002864 -0.025930   141.0
# 3  0.034309  0.022692 -0.009362   206.0
# 4 -0.002592 -0.031991 -0.046641   135.0

# %% [markdown]
# ## 분류 - `DecisionTreeClassifier()`
#
# * `DecisionTreeClassifier`는 분류를 위한 결정트리 모델
# * 두개의 배열 X, y를 입력 받음
#   * X는 [n_samples, n_features] 크기의 데이터 특성 배열
#   * y는 [n_samples] 크기의 정답 배열

# %%
X = [[0,0], [1,1]] #질문
y = [ 0, 1 ] #답

model = tree.DecisionTreeClassifier()
model = model.fit(X,y)

# %%
model.predict([[2.,2.]])
# Out:
# array([1])

# %%
model.predict_proba([[2.,2.]]) #proba는 확률적으로 어디에 가까운지가 나옴
# Out:
# array([[0., 1.]])

# %% [markdown]
# ### 붓꽃 데이터 학습

# %% [markdown]
# #### 교차검증

# %% [markdown]
# ##### 전처리 없이 학습

# %%
model = DecisionTreeClassifier()

# %%
cross_val_score(
    estimator=model,
    X=iris.data, y=iris.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([0.96666667, 0.96666667, 0.9       , 0.96666667, 1.        ])

# %% [markdown]
# ##### 전처리 후 학습
# * 결정 트리는 규칙을 학습하기 때문에 전처리에 큰 영향을 받지 않는다.

# %%
model = make_pipeline(
    StandardScaler(),
    DecisionTreeClassifier()
) #전처리를 해도 별 효과 x

# %%
cross_val_score(
    estimator = model,
    X=iris.data, y=iris.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([0.96666667, 0.96666667, 0.9       , 1.        , 1.        ])

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %%
model = DecisionTreeClassifier()
model.fit(iris.data, iris.target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ##### 텍스트를 통한 시각화

# %%
r = tree.export_text(decision_tree=model,
                    feature_names=iris.feature_names)
print(r)
# Out:
# |--- petal width (cm) <= 0.80
# |   |--- class: 0
# |--- petal width (cm) >  0.80
# |   |--- petal width (cm) <= 1.75
# |   |   |--- petal length (cm) <= 4.95
# |   |   |   |--- petal width (cm) <= 1.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- petal width (cm) >  1.65
# |   |   |   |   |--- class: 2
# |   |   |--- petal length (cm) >  4.95
# |   |   |   |--- petal width (cm) <= 1.55
# |   |   |   |   |--- class: 2
# |   |   |   |--- petal width (cm) >  1.55
# |   |   |   |   |--- sepal length (cm) <= 6.95
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- sepal length (cm) >  6.95
# |   |   |   |   |   |--- class: 2
# |   |--- petal width (cm) >  1.75
# |   |   |--- petal length (cm) <= 4.85
# |   |   |   |--- sepal width (cm) <= 3.10
# |   |   |   |   |--- class: 2
# |   |   |   |--- sepal width (cm) >  3.10
# |   |   |   |   |--- class: 1
# |   |   |--- petal length (cm) >  4.85
# |   |   |   |--- class: 2

# %% [markdown]
# ##### plot_tree를 사용한 시각화

# %%
tree.plot_tree(model)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'X[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# ##### graphviz를 사용한 시각화

# %%
dot_data = tree.export_graphviz(decision_tree=model,
                               feature_names=iris.feature_names,
                                class_names=iris.target_names,
                                filled=True, rounded=True,
                                special_characters=True
                               )
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# #### 시각화

# %%
n_classes = 3
plot_colors = 'ryb' #red yellow blue
plot_step = 0.02

# %% [markdown]
# ##### 결정 경계 시각화

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([[0,1], [0,2], [0,3],
                                 [1,2],[1,3],[2,3]]):
    X = iris.data[:, pair]
    y = iris.target
    
    model = DecisionTreeClassifier()
    model = model.fit(X,y)
    
    plt.subplot(2,3 ,pairidx + 1)
    
    x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
    y_min, y_max = X[:,1].min()-1, X[:,1].max()+1
    xx, yy = np.meshgrid( np.arange(x_min, x_max, plot_step),
                        np.arange(y_min, y_max, plot_step))
    plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
    
    Z=model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
    
    plt.xlabel(iris.feature_names[pair[0]])
    plt.ylabel(iris.feature_names[pair[1]])
    
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y==i)
        plt.scatter(X[idx, 0], X[idx, 1], c = color, label=iris.target_names[i],
                   cmap = plt.cm.RdYlBu, edgecolors='b', s=15)
    
    plt.suptitle("Decision surface")
    plt.legend(loc = 'lower right', borderpad=0, handletextpad=0)
    plt.axis('tight')

# %% [markdown]
# ##### 하이퍼파리미터를 변경해 보면서 결정 경계의 변화 확인

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([[0,1], [0,2], [0,3],
                                 [1,2],[1,3],[2,3]]):
    X = iris.data[:, pair]
    y = iris.target
    
    model = DecisionTreeClassifier(max_depth=2)
    model = model.fit(X,y)
    
    plt.subplot(2,3 ,pairidx + 1)
    
    x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
    y_min, y_max = X[:,1].min()-1, X[:,1].max()+1
    xx, yy = np.meshgrid( np.arange(x_min, x_max, plot_step),
                        np.arange(y_min, y_max, plot_step))
    plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
    
    Z=model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
    
    plt.xlabel(iris.feature_names[pair[0]])
    plt.ylabel(iris.feature_names[pair[1]])
    
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y==i)
        plt.scatter(X[idx, 0], X[idx, 1], c = color, label=iris.target_names[i],
                   cmap = plt.cm.RdYlBu, edgecolors='b', s=15)
    
    plt.suptitle("Decision surface")
    plt.legend(loc = 'lower right', borderpad=0, handletextpad=0)
    plt.axis('tight')

# %% [markdown]
# ### 와인 데이터 학습

# %% [markdown]
# #### 교차검증

# %% [markdown]
# ##### 전처리 없이 학습

# %%
model = DecisionTreeClassifier()

# %%
cross_val_score(
    estimator=model,
    X=wine.data, y=wine.target,
    cv=5,
    n_jobs= multiprocessing.cpu_count()
)
# Out:
# array([0.91666667, 0.86111111, 0.91666667, 0.91428571, 0.82857143])

# %% [markdown]
# ##### 전처리 후 학습
# * 결정 트리는 규칙을 학습하기 때문에 전처리에 큰 영향을 받지 않는다.

# %%
model = make_pipeline(
    StandardScaler(),
    DecisionTreeClassifier()
)

# %%
cross_val_score(
    estimator=model,
    X=wine.data, y=wine.target,
    cv=5,
    n_jobs= multiprocessing.cpu_count()
)
# Out:
# array([0.94444444, 0.83333333, 0.83333333, 0.91428571, 0.85714286])

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %%
model = DecisionTreeClassifier()
model.fit(wine.data, wine.target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ##### 텍스트를 통한 시각화

# %%
r = tree.export_text(decision_tree=model,
                    feature_names=wine.feature_names)
print(r)
# Out:
# |--- proline <= 755.00
# |   |--- od280/od315_of_diluted_wines <= 2.11
# |   |   |--- hue <= 0.94
# |   |   |   |--- flavanoids <= 1.58
# |   |   |   |   |--- class: 2
# |   |   |   |--- flavanoids >  1.58
# |   |   |   |   |--- class: 1
# |   |   |--- hue >  0.94
# |   |   |   |--- flavanoids <= 0.56
# |   |   |   |   |--- class: 2
# |   |   |   |--- flavanoids >  0.56
# |   |   |   |   |--- class: 1
# |   |--- od280/od315_of_diluted_wines >  2.11
# |   |   |--- flavanoids <= 0.80
# |   |   |   |--- class: 2
# |   |   |--- flavanoids >  0.80
# |   |   |   |--- alcohol <= 13.17
# |   |   |   |   |--- class: 1
# |   |   |   |--- alcohol >  13.17
# |   |   |   |   |--- malic_acid <= 2.12
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- malic_acid >  2.12
# |   |   |   |   |   |--- class: 0
# |--- proline >  755.00
# |   |--- flavanoids <= 2.17
# |   |   |--- malic_acid <= 2.08
# |   |   |   |--- class: 1
# |   |   |--- malic_acid >  2.08
# |   |   |   |--- class: 2
# |   |--- flavanoids >  2.17
# |   |   |--- magnesium <= 135.50
# |   |   |   |--- class: 0
# |   |   |--- magnesium >  135.50
# |   |   |   |--- class: 1

# %% [markdown]
# ##### plot_tree를 사용한 시각화

# %%
tree.plot_tree(model)
# Out:
# [Text(0.5657894736842105, 0.9166666666666666, 'X[12] <= 755.0\ngini = 0.658\nsamples = 178\nvalue = [59, 71, 48]'),
#  Text(0.34210526315789475, 0.75, 'X[11] <= 2.115\ngini = 0.492\nsamples = 111\nvalue = [2, 67, 42]'),
#  Text(0.21052631578947367, 0.5833333333333334, 'X[10] <= 0.935\ngini = 0.227\nsamples = 46\nvalue = [0, 6, 40]'),
#  Text(0.10526315789473684, 0.4166666666666667, 'X[6] <= 1.58\ngini = 0.049\nsamples = 40\nvalue = [0, 1, 39]'),
#  Text(0.05263157894736842, 0.25, 'gini = 0.0\nsamples = 39\nvalue = [0, 0, 39]'),
#  Text(0.15789473684210525, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3157894736842105, 0.4166666666666667, 'X[6] <= 0.565\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(0.2631578947368421, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3684210526315789, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.47368421052631576, 0.5833333333333334, 'X[6] <= 0.795\ngini = 0.117\nsamples = 65\nvalue = [2, 61, 2]'),
#  Text(0.42105263157894735, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.5263157894736842, 0.4166666666666667, 'X[0] <= 13.175\ngini = 0.061\nsamples = 63\nvalue = [2, 61, 0]'),
#  Text(0.47368421052631576, 0.25, 'gini = 0.0\nsamples = 58\nvalue = [0, 58, 0]'),
#  Text(0.5789473684210527, 0.25, 'X[1] <= 2.125\ngini = 0.48\nsamples = 5\nvalue = [2, 3, 0]'),
#  Text(0.5263157894736842, 0.08333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.631578947368421, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.7894736842105263, 0.75, 'X[6] <= 2.165\ngini = 0.265\nsamples = 67\nvalue = [57, 4, 6]'),
#  Text(0.6842105263157895, 0.5833333333333334, 'X[1] <= 2.085\ngini = 0.375\nsamples = 8\nvalue = [0, 2, 6]'),
#  Text(0.631578947368421, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.7368421052631579, 0.4166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6]'),
#  Text(0.8947368421052632, 0.5833333333333334, 'X[4] <= 135.5\ngini = 0.065\nsamples = 59\nvalue = [57, 2, 0]'),
#  Text(0.8421052631578947, 0.4166666666666667, 'gini = 0.0\nsamples = 57\nvalue = [57, 0, 0]'),
#  Text(0.9473684210526315, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]')]

# %% [markdown]
# ##### graphviz를 사용한 시각화

# %%
dot_data = tree.export_graphviz(decision_tree=model,
                               feature_names=wine.feature_names,
                                class_names=wine.target_names,
                                filled=True, rounded=True,
                                special_characters=True
                                )

graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# #### 시각화

# %%
n_classes = 3
plot_colors = 'ryb'
plot_step = 0.02

# %% [markdown]
# ##### 결정 경계 시각화

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([[0,1], [0,2], [0,3],
                                 [1,2],[1,3],[2,3]]):
    X = wine.data[:, pair]
    y = wine.target
    
    model = DecisionTreeClassifier()
    model = model.fit(X,y)
    
    plt.subplot(2,3 ,pairidx + 1)
    
    x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
    y_min, y_max = X[:,1].min()-1, X[:,1].max()+1
    xx, yy = np.meshgrid( np.arange(x_min, x_max, plot_step),
                        np.arange(y_min, y_max, plot_step))
    plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
    
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
    
    plt.xlabel(wine.feature_names[pair[0]])
    plt.ylabel(wine.feature_names[pair[1]])
    
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y==i)
        plt.scatter(X[idx, 0], X[idx, 1], c = color, label=wine.target_names[i],
                   cmap = plt.cm.RdYlBu, edgecolors='b', s=15)
    
    plt.suptitle("Decision surface")
    plt.legend(loc = 'lower right', borderpad=0, handletextpad=0)
    plt.axis('tight')

# %% [markdown]
# ##### 하이퍼파리미터를 변경해 보면서 결정 경계의 변화 확인

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([[0,1], [0,2], [0,3],
                                 [1,2],[1,3],[2,3]]):
    X = wine.data[:, pair]
    y = wine.target
    
    model = DecisionTreeClassifier(max_depth=2)
    model = model.fit(X,y)
    
    plt.subplot(2,3 ,pairidx + 1)
    
    x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
    y_min, y_max = X[:,1].min()-1, X[:,1].max()+1
    xx, yy = np.meshgrid( np.arange(x_min, x_max, plot_step),
                        np.arange(y_min, y_max, plot_step))
    plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
    
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
    
    plt.xlabel(wine.feature_names[pair[0]])
    plt.ylabel(wine.feature_names[pair[1]])
    
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y==i)
        plt.scatter(X[idx, 0], X[idx, 1], c = color, label=wine.target_names[i],
                   cmap = plt.cm.RdYlBu, edgecolors='b', s=15)
    
    plt.suptitle("Decision surface")
    plt.legend(loc = 'lower right', borderpad=0, handletextpad=0)
    plt.axis('tight')

# %% [markdown]
# ### 유방암 데이터 학습

# %% [markdown]
# #### 교차검증

# %% [markdown]
# ##### 전처리 없이 학습

# %%
model = DecisionTreeClassifier()

# %%
cross_val_score(
    estimator=model,
    X=cancer.data, y=cancer.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([0.90350877, 0.9122807 , 0.9122807 , 0.92105263, 0.90265487])

# %% [markdown]
# ##### 전처리 후 학습
# * 결정 트리는 규칙을 학습하기 때문에 전처리에 큰 영향을 받지 않는다.

# %%
model = make_pipeline(
    StandardScaler(),
    DecisionTreeClassifier()
)

# %%
cross_val_score(
    estimator=model,
    X=cancer.data, y=cancer.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([0.9122807 , 0.92105263, 0.92105263, 0.93859649, 0.89380531])

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %%
model = DecisionTreeClassifier()
model.fit(cancer.data, cancer.target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ##### 텍스트를 통한 시각화

# %%
r = tree.export_text(decision_tree=model)
print(r)
# Out:
# |--- feature_20 <= 16.80
# |   |--- feature_27 <= 0.14
# |   |   |--- feature_12 <= 6.60
# |   |   |   |--- feature_13 <= 38.60
# |   |   |   |   |--- feature_14 <= 0.00
# |   |   |   |   |   |--- feature_19 <= 0.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_19 >  0.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_14 >  0.00
# |   |   |   |   |   |--- feature_21 <= 33.27
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_21 >  33.27
# |   |   |   |   |   |   |--- feature_21 <= 33.56
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_21 >  33.56
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_13 >  38.60
# |   |   |   |   |--- feature_25 <= 0.08
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_25 >  0.08
# |   |   |   |   |   |--- feature_10 <= 0.42
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_10 >  0.42
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_12 >  6.60
# |   |   |   |--- class: 0
# |   |--- feature_27 >  0.14
# |   |   |--- feature_21 <= 25.67
# |   |   |   |--- feature_23 <= 810.30
# |   |   |   |   |--- feature_24 <= 0.18
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_24 >  0.18
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_23 >  810.30
# |   |   |   |   |--- feature_12 <= 2.62
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_12 >  2.62
# |   |   |   |   |   |--- class: 1
# |   |   |--- feature_21 >  25.67
# |   |   |   |--- feature_7 <= 0.05
# |   |   |   |   |--- feature_1 <= 20.45
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_1 >  20.45
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_7 >  0.05
# |   |   |   |   |--- class: 0
# |--- feature_20 >  16.80
# |   |--- feature_1 <= 16.11
# |   |   |--- feature_27 <= 0.15
# |   |   |   |--- class: 1
# |   |   |--- feature_27 >  0.15
# |   |   |   |--- class: 0
# |   |--- feature_1 >  16.11
# |   |   |--- feature_24 <= 0.09
# |   |   |   |--- class: 1
# |   |   |--- feature_24 >  0.09
# |   |   |   |--- feature_26 <= 0.18
# |   |   |   |   |--- feature_15 <= 0.02
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_15 >  0.02
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_26 >  0.18
# |   |   |   |   |--- class: 0

# %% [markdown]
# ##### plot_tree를 사용한 시각화

# %%
tree.plot_tree(model)
# Out:
# [Text(0.625, 0.9375, 'X[20] <= 16.795\ngini = 0.468\nsamples = 569\nvalue = [212, 357]'),
#  Text(0.40625, 0.8125, 'X[27] <= 0.136\ngini = 0.159\nsamples = 379\nvalue = [33, 346]'),
#  Text(0.234375, 0.6875, 'X[12] <= 6.597\ngini = 0.03\nsamples = 333\nvalue = [5, 328]'),
#  Text(0.203125, 0.5625, 'X[13] <= 38.605\ngini = 0.024\nsamples = 332\nvalue = [4, 328]'),
#  Text(0.125, 0.4375, 'X[14] <= 0.003\ngini = 0.012\nsamples = 319\nvalue = [2, 317]'),
#  Text(0.0625, 0.3125, 'X[19] <= 0.001\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.03125, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09375, 0.1875, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.1875, 0.3125, 'X[21] <= 33.27\ngini = 0.006\nsamples = 312\nvalue = [1, 311]'),
#  Text(0.15625, 0.1875, 'gini = 0.0\nsamples = 292\nvalue = [0, 292]'),
#  Text(0.21875, 0.1875, 'X[21] <= 33.56\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(0.1875, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25, 0.0625, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.28125, 0.4375, 'X[25] <= 0.082\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.25, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3125, 0.3125, 'X[10] <= 0.421\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.28125, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34375, 0.1875, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.265625, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.578125, 0.6875, 'X[21] <= 25.67\ngini = 0.476\nsamples = 46\nvalue = [28, 18]'),
#  Text(0.46875, 0.5625, 'X[23] <= 810.3\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(0.40625, 0.4375, 'X[24] <= 0.179\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.375, 0.3125, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.4375, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.53125, 0.4375, 'X[12] <= 2.62\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5625, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6875, 0.5625, 'X[7] <= 0.054\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.65625, 0.4375, 'X[1] <= 20.455\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.625, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6875, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.71875, 0.4375, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.84375, 0.8125, 'X[1] <= 16.11\ngini = 0.109\nsamples = 190\nvalue = [179, 11]'),
#  Text(0.78125, 0.6875, 'X[27] <= 0.145\ngini = 0.498\nsamples = 17\nvalue = [8, 9]'),
#  Text(0.75, 0.5625, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.8125, 0.5625, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.90625, 0.6875, 'X[24] <= 0.088\ngini = 0.023\nsamples = 173\nvalue = [171, 2]'),
#  Text(0.875, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9375, 0.5625, 'X[26] <= 0.18\ngini = 0.012\nsamples = 172\nvalue = [171, 1]'),
#  Text(0.90625, 0.4375, 'X[15] <= 0.016\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.875, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9375, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.96875, 0.4375, 'gini = 0.0\nsamples = 168\nvalue = [168, 0]')]

# %% [markdown]
# ##### graphviz를 사용한 시각화

# %%
dot_data = tree.export_graphviz(decision_tree=model,
                                feature_names=cancer.feature_names,
                                class_names=cancer.target_names,
                                rounded=True, filled=True,
                                special_characters=True)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# #### 시각화

# %%
n_classes = 2
plot_colors = 'ryb'
plot_step = 0.02

# %% [markdown]
# ##### 결정 경계 시각화

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([[0,1], [0,2], [0,3]]):
    X = cancer.data[:, pair]
    y = cancer.target
    
    model = DecisionTreeClassifier()
    model = model.fit(X,y)
    
    plt.subplot(2,3 ,pairidx + 1)
    
    x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
    y_min, y_max = X[:,1].min()-1, X[:,1].max()+1
    xx, yy = np.meshgrid( np.arange(x_min, x_max, plot_step),
                        np.arange(y_min, y_max, plot_step))
    plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
    
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
    
    plt.xlabel(cancer.feature_names[pair[0]])
    plt.ylabel(cancer.feature_names[pair[1]])
    
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y==i)
        plt.scatter(X[idx, 0], X[idx, 1], c = color, label=cancer.target_names[i],
                   cmap = plt.cm.RdYlBu, edgecolors='b', s=15)
    
    plt.suptitle("Decision surface")
    plt.legend(loc = 'lower right', borderpad=0, handletextpad=0)
    plt.axis('tight')

# %% [markdown]
# ##### 하이퍼파리미터를 변경해 보면서 결정 경계의 변화 확인

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([[0,1], [0,2], [0,3]]):
    X = cancer.data[:, pair]
    y = cancer.target
    
    model = DecisionTreeClassifier(max_depth=2)
    model = model.fit(X,y)
    
    plt.subplot(2,3 ,pairidx + 1)
    
    x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
    y_min, y_max = X[:,1].min()-1, X[:,1].max()+1
    xx, yy = np.meshgrid( np.arange(x_min, x_max, plot_step),
                        np.arange(y_min, y_max, plot_step))
    plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
    
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
    
    plt.xlabel(cancer.feature_names[pair[0]])
    plt.ylabel(cancer.feature_names[pair[1]])
    
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y==i)
        plt.scatter(X[idx, 0], X[idx, 1], c = color, label=cancer.target_names[i],
                   cmap = plt.cm.RdYlBu, edgecolors='b', s=15)
    
    plt.suptitle("Decision surface")
    plt.legend(loc = 'lower right', borderpad=0, handletextpad=0)
    plt.axis('tight')

# %% [markdown]
# ## 회귀 - `DecisionTreeRegressor()`

# %% [markdown]
# ### 보스턴 주택 가격 데이터 학습

# %% [markdown]
# #### 교차검증

# %% [markdown]
# ##### 전처리 없이 학습

# %%
model =DecisionTreeRegressor()

# %%
cross_val_score(
    estimator=model,
    X=boston.data, y=boston.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([ 0.61597006,  0.41089727,  0.65138372,  0.41252393, -1.78496846])

# %% [markdown]
# ##### 전처리 후 학습
# * 결정 트리는 규칙을 학습하기 때문에 전처리에 큰 영향을 받지 않는다.

# %%
model = make_pipeline(StandardScaler(), DecisionTreeRegressor())

# %%
cross_val_score(
    estimator=model,
    X=boston.data, y=boston.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([ 0.59481517,  0.41059492,  0.66376379,  0.38922984, -1.4678002 ])

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %%
model = DecisionTreeRegressor()
model.fit(boston.data, boston.target)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ##### 텍스트를 통한 시각화

# %%
print(tree.export_text(model))
# Out:
# |--- feature_5 <= 6.94
# |   |--- feature_12 <= 14.40
# |   |   |--- feature_7 <= 1.38
# |   |   |   |--- feature_12 <= 10.83
# |   |   |   |   |--- value: [50.00]
# |   |   |   |--- feature_12 >  10.83
# |   |   |   |   |--- value: [27.90]
# |   |   |--- feature_7 >  1.38
# |   |   |   |--- feature_5 <= 6.54
# |   |   |   |   |--- feature_12 <= 7.57
# |   |   |   |   |   |--- feature_9 <= 222.50
# |   |   |   |   |   |   |--- value: [28.70]
# |   |   |   |   |   |--- feature_9 >  222.50
# |   |   |   |   |   |   |--- feature_2 <= 5.48
# |   |   |   |   |   |   |   |--- feature_10 <= 19.95
# |   |   |   |   |   |   |   |   |--- feature_11 <= 393.33
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 3.90
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [21.90]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  3.90
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 23.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.70]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  23.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_11 >  393.33
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.42
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.42
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [22.90]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [22.20]
# |   |   |   |   |   |   |   |--- feature_10 >  19.95
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.31
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 382.72
# |   |   |   |   |   |   |   |   |   |   |--- value: [20.60]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  382.72
# |   |   |   |   |   |   |   |   |   |   |--- value: [20.70]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.31
# |   |   |   |   |   |   |   |   |   |--- value: [22.20]
# |   |   |   |   |   |   |--- feature_2 >  5.48
# |   |   |   |   |   |   |   |--- feature_1 <= 34.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 359.51
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 96.30
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 18.84
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [27.50]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  18.84
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [27.00]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  96.30
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.30]
# |   |   |   |   |   |   |   |   |--- feature_11 >  359.51
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.15
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 304.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [22.10]
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  304.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.15
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 278.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  278.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- feature_1 >  34.00
# |   |   |   |   |   |   |   |   |--- value: [29.10]
# |   |   |   |   |--- feature_12 >  7.57
# |   |   |   |   |   |--- feature_9 <= 208.00
# |   |   |   |   |   |   |--- feature_5 <= 6.07
# |   |   |   |   |   |   |   |--- feature_8 <= 2.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.07
# |   |   |   |   |   |   |   |   |   |--- value: [22.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.07
# |   |   |   |   |   |   |   |   |   |--- value: [20.30]
# |   |   |   |   |   |   |   |--- feature_8 >  2.50
# |   |   |   |   |   |   |   |   |--- value: [26.40]
# |   |   |   |   |   |   |--- feature_5 >  6.07
# |   |   |   |   |   |   |   |--- feature_12 <= 11.30
# |   |   |   |   |   |   |   |   |--- value: [36.20]
# |   |   |   |   |   |   |   |--- feature_12 >  11.30
# |   |   |   |   |   |   |   |   |--- value: [29.60]
# |   |   |   |   |   |--- feature_9 >  208.00
# |   |   |   |   |   |   |--- feature_5 <= 6.08
# |   |   |   |   |   |   |   |--- feature_6 <= 69.10
# |   |   |   |   |   |   |   |   |--- feature_7 <= 4.46
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.21
# |   |   |   |   |   |   |   |   |   |   |--- value: [16.10]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.21
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 17.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  17.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_7 >  4.46
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.76
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 294.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  294.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.76
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 5.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  5.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- feature_6 >  69.10
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.03
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [15.30]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.03
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.70
# |   |   |   |   |   |   |   |   |   |   |--- value: [11.90]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.70
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.50]
# |   |   |   |   |   |   |--- feature_5 >  6.08
# |   |   |   |   |   |   |   |--- feature_12 <= 9.98
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.05
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 2.07
# |   |   |   |   |   |   |   |   |   |   |--- value: [16.50]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  2.07
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.05
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 33.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 8.62
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.90]
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  8.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  33.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 9.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  9.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_12 >  9.98
# |   |   |   |   |   |   |   |   |--- feature_11 <= 197.52
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 11.33
# |   |   |   |   |   |   |   |   |   |   |--- value: [18.60]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  11.33
# |   |   |   |   |   |   |   |   |   |   |--- value: [16.10]
# |   |   |   |   |   |   |   |   |--- feature_11 >  197.52
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 20.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  20.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 3.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  3.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |--- feature_5 >  6.54
# |   |   |   |   |--- feature_9 <= 269.00
# |   |   |   |   |   |--- feature_10 <= 17.85
# |   |   |   |   |   |   |--- feature_11 <= 393.41
# |   |   |   |   |   |   |   |--- feature_11 <= 392.41
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.67
# |   |   |   |   |   |   |   |   |   |--- value: [29.10]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.67
# |   |   |   |   |   |   |   |   |   |--- value: [30.10]
# |   |   |   |   |   |   |   |--- feature_11 >  392.41
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.41
# |   |   |   |   |   |   |   |   |   |--- value: [31.10]
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.41
# |   |   |   |   |   |   |   |   |   |--- value: [31.60]
# |   |   |   |   |   |   |--- feature_11 >  393.41
# |   |   |   |   |   |   |   |--- feature_4 <= 0.44
# |   |   |   |   |   |   |   |   |--- value: [35.10]
# |   |   |   |   |   |   |   |--- feature_4 >  0.44
# |   |   |   |   |   |   |   |   |--- feature_11 <= 395.18
# |   |   |   |   |   |   |   |   |   |--- value: [33.10]
# |   |   |   |   |   |   |   |   |--- feature_11 >  395.18
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.81
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.50]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.40]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.81
# |   |   |   |   |   |   |   |   |   |   |--- value: [32.00]
# |   |   |   |   |   |--- feature_10 >  17.85
# |   |   |   |   |   |   |--- feature_9 <= 249.50
# |   |   |   |   |   |   |   |--- feature_11 <= 392.83
# |   |   |   |   |   |   |   |   |--- value: [26.60]
# |   |   |   |   |   |   |   |--- feature_11 >  392.83
# |   |   |   |   |   |   |   |   |--- feature_6 <= 25.65
# |   |   |   |   |   |   |   |   |   |--- value: [27.90]
# |   |   |   |   |   |   |   |   |--- feature_6 >  25.65
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 64.20
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 56.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [28.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  56.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [28.50]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  64.20
# |   |   |   |   |   |   |   |   |   |   |--- value: [28.20]
# |   |   |   |   |   |   |--- feature_9 >  249.50
# |   |   |   |   |   |   |   |--- value: [30.80]
# |   |   |   |   |--- feature_9 >  269.00
# |   |   |   |   |   |--- feature_4 <= 0.53
# |   |   |   |   |   |   |--- feature_4 <= 0.44
# |   |   |   |   |   |   |   |--- feature_6 <= 35.20
# |   |   |   |   |   |   |   |   |--- feature_10 <= 18.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.60
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.80]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.60
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.50]
# |   |   |   |   |   |   |   |   |--- feature_10 >  18.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.43
# |   |   |   |   |   |   |   |   |   |   |--- value: [28.00]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.43
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [26.60]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [26.20]
# |   |   |   |   |   |   |   |--- feature_6 >  35.20
# |   |   |   |   |   |   |   |   |--- feature_12 <= 8.43
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.80]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 17.45
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.30]
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  17.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_12 >  8.43
# |   |   |   |   |   |   |   |   |   |--- value: [22.00]
# |   |   |   |   |   |   |--- feature_4 >  0.44
# |   |   |   |   |   |   |   |--- feature_12 <= 7.05
# |   |   |   |   |   |   |   |   |--- feature_9 <= 301.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 4.73
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [28.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  4.73
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [28.60]
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.70
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [29.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.70
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [29.90]
# |   |   |   |   |   |   |   |   |--- feature_9 >  301.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 4.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 387.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [31.50]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  387.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.00]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  4.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 5.52
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [29.80]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  5.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_12 >  7.05
# |   |   |   |   |   |   |   |   |--- feature_7 <= 3.90
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.73
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [29.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [30.10]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.73
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 395.17
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [27.50]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  395.17
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [26.50]
# |   |   |   |   |   |   |   |   |--- feature_7 >  3.90
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 16.70
# |   |   |   |   |   |   |   |   |   |   |--- value: [27.10]
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  16.70
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 40.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  40.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.90]
# |   |   |   |   |   |--- feature_4 >  0.53
# |   |   |   |   |   |   |--- feature_10 <= 17.10
# |   |   |   |   |   |   |   |--- feature_11 <= 394.84
# |   |   |   |   |   |   |   |   |--- value: [28.70]
# |   |   |   |   |   |   |   |--- feature_11 >  394.84
# |   |   |   |   |   |   |   |   |--- value: [24.00]
# |   |   |   |   |   |   |--- feature_10 >  17.10
# |   |   |   |   |   |   |   |--- feature_10 <= 20.60
# |   |   |   |   |   |   |   |   |--- feature_7 <= 3.32
# |   |   |   |   |   |   |   |   |   |--- value: [22.80]
# |   |   |   |   |   |   |   |   |--- feature_7 >  3.32
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 485.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [23.80]
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  485.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [23.70]
# |   |   |   |   |   |   |   |--- feature_10 >  20.60
# |   |   |   |   |   |   |   |   |--- feature_9 <= 290.00
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 8.08
# |   |   |   |   |   |   |   |   |   |   |--- value: [22.00]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  8.08
# |   |   |   |   |   |   |   |   |   |   |--- value: [22.40]
# |   |   |   |   |   |   |   |   |--- feature_9 >  290.00
# |   |   |   |   |   |   |   |   |   |--- value: [21.00]
# |   |--- feature_12 >  14.40
# |   |   |--- feature_0 <= 6.99
# |   |   |   |--- feature_4 <= 0.53
# |   |   |   |   |--- feature_7 <= 5.57
# |   |   |   |   |   |--- feature_6 <= 88.55
# |   |   |   |   |   |   |--- feature_11 <= 385.38
# |   |   |   |   |   |   |   |--- feature_0 <= 0.21
# |   |   |   |   |   |   |   |   |--- value: [24.40]
# |   |   |   |   |   |   |   |--- feature_0 >  0.21
# |   |   |   |   |   |   |   |   |--- value: [23.70]
# |   |   |   |   |   |   |--- feature_11 >  385.38
# |   |   |   |   |   |   |   |--- feature_4 <= 0.52
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.18
# |   |   |   |   |   |   |   |   |   |--- value: [23.10]
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.18
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 390.18
# |   |   |   |   |   |   |   |   |   |   |--- value: [22.50]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  390.18
# |   |   |   |   |   |   |   |   |   |   |--- value: [22.40]
# |   |   |   |   |   |   |   |--- feature_4 >  0.52
# |   |   |   |   |   |   |   |   |--- value: [21.70]
# |   |   |   |   |   |--- feature_6 >  88.55
# |   |   |   |   |   |   |--- feature_5 <= 5.91
# |   |   |   |   |   |   |   |--- feature_0 <= 0.41
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [19.30]
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [19.50]
# |   |   |   |   |   |   |   |--- feature_0 >  0.41
# |   |   |   |   |   |   |   |   |--- value: [20.00]
# |   |   |   |   |   |   |--- feature_5 >  5.91
# |   |   |   |   |   |   |   |--- feature_9 <= 345.50
# |   |   |   |   |   |   |   |   |--- value: [21.70]
# |   |   |   |   |   |   |   |--- feature_9 >  345.50
# |   |   |   |   |   |   |   |   |--- value: [19.40]
# |   |   |   |   |--- feature_7 >  5.57
# |   |   |   |   |   |--- feature_0 <= 0.16
# |   |   |   |   |   |   |--- feature_10 <= 15.60
# |   |   |   |   |   |   |   |--- value: [27.10]
# |   |   |   |   |   |   |--- feature_10 >  15.60
# |   |   |   |   |   |   |   |--- feature_7 <= 6.82
# |   |   |   |   |   |   |   |   |--- value: [20.30]
# |   |   |   |   |   |   |   |--- feature_7 >  6.82
# |   |   |   |   |   |   |   |   |--- value: [18.90]
# |   |   |   |   |   |--- feature_0 >  0.16
# |   |   |   |   |   |   |--- feature_6 <= 89.65
# |   |   |   |   |   |   |   |--- feature_7 <= 5.89
# |   |   |   |   |   |   |   |   |--- value: [16.60]
# |   |   |   |   |   |   |   |--- feature_7 >  5.89
# |   |   |   |   |   |   |   |   |--- feature_11 <= 393.01
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 7.27
# |   |   |   |   |   |   |   |   |   |   |--- value: [18.90]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  7.27
# |   |   |   |   |   |   |   |   |   |   |--- value: [18.50]
# |   |   |   |   |   |   |   |   |--- feature_11 >  393.01
# |   |   |   |   |   |   |   |   |   |--- value: [19.40]
# |   |   |   |   |   |   |--- feature_6 >  89.65
# |   |   |   |   |   |   |   |--- feature_0 <= 0.22
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.49
# |   |   |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.49
# |   |   |   |   |   |   |   |   |   |--- value: [16.50]
# |   |   |   |   |   |   |   |--- feature_0 >  0.22
# |   |   |   |   |   |   |   |   |--- feature_1 <= 6.25
# |   |   |   |   |   |   |   |   |   |--- value: [14.40]
# |   |   |   |   |   |   |   |   |--- feature_1 >  6.25
# |   |   |   |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |--- feature_4 >  0.53
# |   |   |   |   |--- feature_12 <= 18.89
# |   |   |   |   |   |--- feature_6 <= 85.20
# |   |   |   |   |   |   |--- feature_12 <= 15.24
# |   |   |   |   |   |   |   |--- feature_8 <= 15.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [17.50]
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [15.60]
# |   |   |   |   |   |   |   |--- feature_8 >  15.00
# |   |   |   |   |   |   |   |   |--- feature_12 <= 14.84
# |   |   |   |   |   |   |   |   |   |--- value: [20.00]
# |   |   |   |   |   |   |   |   |--- feature_12 >  14.84
# |   |   |   |   |   |   |   |   |   |--- value: [19.10]
# |   |   |   |   |   |   |--- feature_12 >  15.24
# |   |   |   |   |   |   |   |--- feature_7 <= 2.84
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.15
# |   |   |   |   |   |   |   |   |   |--- value: [20.40]
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.15
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 385.84
# |   |   |   |   |   |   |   |   |   |   |--- value: [23.20]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  385.84
# |   |   |   |   |   |   |   |   |   |   |--- value: [23.10]
# |   |   |   |   |   |   |   |--- feature_7 >  2.84
# |   |   |   |   |   |   |   |   |--- feature_12 <= 17.74
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.62
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 485.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [19.80]
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  485.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [19.90]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.62
# |   |   |   |   |   |   |   |   |   |   |--- value: [19.00]
# |   |   |   |   |   |   |   |   |--- feature_12 >  17.74
# |   |   |   |   |   |   |   |   |   |--- value: [17.80]
# |   |   |   |   |   |--- feature_6 >  85.20
# |   |   |   |   |   |   |--- feature_9 <= 291.50
# |   |   |   |   |   |   |   |--- feature_5 <= 5.92
# |   |   |   |   |   |   |   |   |--- value: [18.80]
# |   |   |   |   |   |   |   |--- feature_5 >  5.92
# |   |   |   |   |   |   |   |   |--- feature_12 <= 17.93
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [21.40]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [21.50]
# |   |   |   |   |   |   |   |   |--- feature_12 >  17.93
# |   |   |   |   |   |   |   |   |   |--- value: [20.50]
# |   |   |   |   |   |   |--- feature_9 >  291.50
# |   |   |   |   |   |   |   |--- feature_12 <= 17.10
# |   |   |   |   |   |   |   |   |--- feature_5 <= 5.67
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1.63
# |   |   |   |   |   |   |   |   |   |   |--- value: [15.60]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1.63
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1.64
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.90]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  1.64
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.10]
# |   |   |   |   |   |   |   |   |--- feature_5 >  5.67
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 177.71
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.30]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  177.71
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_12 >  17.10
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.80
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 394.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [16.20]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  394.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [17.80]
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.80
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 18.52
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 18.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  18.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  18.52
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 486.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [15.20]
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  486.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [16.70]
# |   |   |   |   |--- feature_12 >  18.89
# |   |   |   |   |   |--- feature_2 <= 26.69
# |   |   |   |   |   |   |--- feature_6 <= 77.45
# |   |   |   |   |   |   |   |--- value: [19.70]
# |   |   |   |   |   |   |--- feature_6 >  77.45
# |   |   |   |   |   |   |   |--- feature_8 <= 3.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 5.73
# |   |   |   |   |   |   |   |   |   |--- value: [15.70]
# |   |   |   |   |   |   |   |   |--- feature_5 >  5.73
# |   |   |   |   |   |   |   |   |   |--- value: [17.30]
# |   |   |   |   |   |   |   |--- feature_8 >  3.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 95.85
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.56
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 372.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  372.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.56
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 25.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  25.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.20]
# |   |   |   |   |   |   |   |   |--- feature_6 >  95.85
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 99.10
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 394.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  394.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  99.10
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 3.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  3.71
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [15.60]
# |   |   |   |   |   |--- feature_2 >  26.69
# |   |   |   |   |   |   |--- feature_11 <= 331.24
# |   |   |   |   |   |   |   |--- value: [8.10]
# |   |   |   |   |   |   |--- feature_11 >  331.24
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |--- feature_0 >  6.99
# |   |   |   |--- feature_4 <= 0.61
# |   |   |   |   |--- feature_5 <= 6.84
# |   |   |   |   |   |--- feature_0 <= 12.66
# |   |   |   |   |   |   |--- feature_12 <= 17.40
# |   |   |   |   |   |   |   |--- feature_11 <= 14.15
# |   |   |   |   |   |   |   |   |--- value: [11.70]
# |   |   |   |   |   |   |   |--- feature_11 >  14.15
# |   |   |   |   |   |   |   |   |--- value: [10.20]
# |   |   |   |   |   |   |--- feature_12 >  17.40
# |   |   |   |   |   |   |   |--- feature_0 <= 7.73
# |   |   |   |   |   |   |   |   |--- value: [17.20]
# |   |   |   |   |   |   |   |--- feature_0 >  7.73
# |   |   |   |   |   |   |   |   |--- feature_7 <= 2.07
# |   |   |   |   |   |   |   |   |   |--- value: [14.50]
# |   |   |   |   |   |   |   |   |--- feature_7 >  2.07
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.06
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.80]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.06
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.10]
# |   |   |   |   |   |--- feature_0 >  12.66
# |   |   |   |   |   |   |--- feature_7 <= 2.21
# |   |   |   |   |   |   |   |--- feature_12 <= 20.65
# |   |   |   |   |   |   |   |   |--- value: [16.30]
# |   |   |   |   |   |   |   |--- feature_12 >  20.65
# |   |   |   |   |   |   |   |   |--- feature_12 <= 27.79
# |   |   |   |   |   |   |   |   |   |--- value: [17.20]
# |   |   |   |   |   |   |   |   |--- feature_12 >  27.79
# |   |   |   |   |   |   |   |   |   |--- value: [17.90]
# |   |   |   |   |   |   |--- feature_7 >  2.21
# |   |   |   |   |   |   |   |--- feature_12 <= 16.44
# |   |   |   |   |   |   |   |   |--- value: [20.10]
# |   |   |   |   |   |   |   |--- feature_12 >  16.44
# |   |   |   |   |   |   |   |   |--- value: [19.10]
# |   |   |   |   |--- feature_5 >  6.84
# |   |   |   |   |   |--- value: [27.50]
# |   |   |   |--- feature_4 >  0.61
# |   |   |   |   |--- feature_12 <= 19.65
# |   |   |   |   |   |--- feature_0 <= 12.22
# |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |--- feature_12 <= 19.41
# |   |   |   |   |   |   |   |   |--- feature_6 <= 99.40
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.73
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 97.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  97.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.73
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.60]
# |   |   |   |   |   |   |   |   |--- feature_6 >  99.40
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 10.53
# |   |   |   |   |   |   |   |   |   |   |--- value: [15.40]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  10.53
# |   |   |   |   |   |   |   |   |   |   |--- value: [16.70]
# |   |   |   |   |   |   |   |--- feature_12 >  19.41
# |   |   |   |   |   |   |   |   |--- value: [17.10]
# |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |--- value: [17.80]
# |   |   |   |   |   |--- feature_0 >  12.22
# |   |   |   |   |   |   |--- feature_11 <= 64.06
# |   |   |   |   |   |   |   |--- feature_5 <= 6.33
# |   |   |   |   |   |   |   |   |--- value: [10.90]
# |   |   |   |   |   |   |   |--- feature_5 >  6.33
# |   |   |   |   |   |   |   |   |--- value: [9.60]
# |   |   |   |   |   |   |--- feature_11 >  64.06
# |   |   |   |   |   |   |   |--- feature_7 <= 2.00
# |   |   |   |   |   |   |   |   |--- value: [12.70]
# |   |   |   |   |   |   |   |--- feature_7 >  2.00
# |   |   |   |   |   |   |   |   |--- value: [11.70]
# |   |   |   |   |--- feature_12 >  19.65
# |   |   |   |   |   |--- feature_4 <= 0.68
# |   |   |   |   |   |   |--- feature_12 <= 22.51
# |   |   |   |   |   |   |   |--- feature_0 <= 12.85
# |   |   |   |   |   |   |   |   |--- value: [13.30]
# |   |   |   |   |   |   |   |--- feature_0 >  12.85
# |   |   |   |   |   |   |   |   |--- feature_0 <= 16.87
# |   |   |   |   |   |   |   |   |   |--- value: [10.90]
# |   |   |   |   |   |   |   |   |--- feature_0 >  16.87
# |   |   |   |   |   |   |   |   |   |--- value: [10.20]
# |   |   |   |   |   |   |--- feature_12 >  22.51
# |   |   |   |   |   |   |   |--- feature_4 <= 0.66
# |   |   |   |   |   |   |   |   |--- feature_11 <= 176.00
# |   |   |   |   |   |   |   |   |   |--- value: [13.40]
# |   |   |   |   |   |   |   |   |--- feature_11 >  176.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4.72
# |   |   |   |   |   |   |   |   |   |   |--- value: [11.90]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  4.72
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.00]
# |   |   |   |   |   |   |   |--- feature_4 >  0.66
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.37
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 379.96
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.90]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  379.96
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.80]
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.37
# |   |   |   |   |   |   |   |   |   |--- value: [13.10]
# |   |   |   |   |   |--- feature_4 >  0.68
# |   |   |   |   |   |   |--- feature_0 <= 13.24
# |   |   |   |   |   |   |   |--- feature_12 <= 25.74
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.73
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 99.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 54.59
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  54.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  99.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 8.59
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [12.30]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  8.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.73
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 23.53
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1.97
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [12.80]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  1.97
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.40]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  23.53
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 141.79
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [11.80]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  141.79
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [10.80]
# |   |   |   |   |   |   |   |--- feature_12 >  25.74
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.69
# |   |   |   |   |   |   |   |   |   |--- value: [7.50]
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.69
# |   |   |   |   |   |   |   |   |   |--- value: [6.30]
# |   |   |   |   |   |   |--- feature_0 >  13.24
# |   |   |   |   |   |   |   |--- feature_7 <= 1.59
# |   |   |   |   |   |   |   |   |--- feature_5 <= 4.83
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 341.36
# |   |   |   |   |   |   |   |   |   |   |--- value: [8.80]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  341.36
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.50]
# |   |   |   |   |   |   |   |   |--- feature_5 >  4.83
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 23.82
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 93.80
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [7.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  93.80
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [7.20]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  23.82
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.84
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.84
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.60]
# |   |   |   |   |   |   |   |--- feature_7 >  1.59
# |   |   |   |   |   |   |   |   |--- feature_11 <= 107.81
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 27.75
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.93
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.30]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  27.75
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.40]
# |   |   |   |   |   |   |   |   |--- feature_11 >  107.81
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 20.94
# |   |   |   |   |   |   |   |   |   |   |--- value: [8.30]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  20.94
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 33.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  33.73
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.50]
# |--- feature_5 >  6.94
# |   |--- feature_5 <= 7.44
# |   |   |--- feature_4 <= 0.66
# |   |   |   |--- feature_7 <= 1.89
# |   |   |   |   |--- feature_6 <= 97.45
# |   |   |   |   |   |--- value: [41.30]
# |   |   |   |   |--- feature_6 >  97.45
# |   |   |   |   |   |--- value: [50.00]
# |   |   |   |--- feature_7 >  1.89
# |   |   |   |   |--- feature_4 <= 0.49
# |   |   |   |   |   |--- feature_6 <= 11.95
# |   |   |   |   |   |   |--- feature_1 <= 46.00
# |   |   |   |   |   |   |   |--- value: [29.60]
# |   |   |   |   |   |   |--- feature_1 >  46.00
# |   |   |   |   |   |   |   |--- value: [29.00]
# |   |   |   |   |   |--- feature_6 >  11.95
# |   |   |   |   |   |   |--- feature_12 <= 5.44
# |   |   |   |   |   |   |   |--- feature_0 <= 0.05
# |   |   |   |   |   |   |   |   |--- feature_12 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 2.57
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 365.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  365.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.90]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  2.57
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 394.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [34.70]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  394.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [34.90]
# |   |   |   |   |   |   |   |   |--- feature_12 >  4.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 396.41
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 55.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [35.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  55.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [35.40]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  396.41
# |   |   |   |   |   |   |   |   |   |   |--- value: [34.90]
# |   |   |   |   |   |   |   |--- feature_0 >  0.05
# |   |   |   |   |   |   |   |   |--- feature_2 <= 5.52
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 5.36
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 5.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  5.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  5.36
# |   |   |   |   |   |   |   |   |   |   |--- value: [34.90]
# |   |   |   |   |   |   |   |   |--- feature_2 >  5.52
# |   |   |   |   |   |   |   |   |   |--- value: [33.10]
# |   |   |   |   |   |   |--- feature_12 >  5.44
# |   |   |   |   |   |   |   |--- feature_6 <= 37.45
# |   |   |   |   |   |   |   |   |--- feature_11 <= 374.51
# |   |   |   |   |   |   |   |   |   |--- value: [30.30]
# |   |   |   |   |   |   |   |   |--- feature_11 >  374.51
# |   |   |   |   |   |   |   |   |   |--- value: [32.20]
# |   |   |   |   |   |   |   |--- feature_6 >  37.45
# |   |   |   |   |   |   |   |   |--- feature_6 <= 45.05
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 6.77
# |   |   |   |   |   |   |   |   |   |   |--- value: [34.60]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  6.77
# |   |   |   |   |   |   |   |   |   |   |--- value: [36.10]
# |   |   |   |   |   |   |   |   |--- feature_6 >  45.05
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 7.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 250.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [33.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  250.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.70]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  7.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 18.20
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [33.20]
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  18.20
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [33.40]
# |   |   |   |   |--- feature_4 >  0.49
# |   |   |   |   |   |--- feature_5 <= 7.12
# |   |   |   |   |   |   |--- feature_11 <= 387.89
# |   |   |   |   |   |   |   |--- feature_7 <= 2.33
# |   |   |   |   |   |   |   |   |--- value: [30.70]
# |   |   |   |   |   |   |   |--- feature_7 >  2.33
# |   |   |   |   |   |   |   |   |--- value: [29.80]
# |   |   |   |   |   |   |--- feature_11 >  387.89
# |   |   |   |   |   |   |   |--- feature_6 <= 70.05
# |   |   |   |   |   |   |   |   |--- value: [28.70]
# |   |   |   |   |   |   |   |--- feature_6 >  70.05
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.96
# |   |   |   |   |   |   |   |   |   |--- value: [26.70]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.96
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 7.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.79
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.90]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.79
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.60]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  7.03
# |   |   |   |   |   |   |   |   |   |   |--- value: [25.00]
# |   |   |   |   |   |--- feature_5 >  7.12
# |   |   |   |   |   |   |--- feature_7 <= 2.00
# |   |   |   |   |   |   |   |--- feature_6 <= 95.80
# |   |   |   |   |   |   |   |   |--- value: [36.50]
# |   |   |   |   |   |   |   |--- feature_6 >  95.80
# |   |   |   |   |   |   |   |   |--- value: [36.00]
# |   |   |   |   |   |   |--- feature_7 >  2.00
# |   |   |   |   |   |   |   |--- feature_5 <= 7.27
# |   |   |   |   |   |   |   |   |--- feature_11 <= 382.44
# |   |   |   |   |   |   |   |   |   |--- value: [31.60]
# |   |   |   |   |   |   |   |   |--- feature_11 >  382.44
# |   |   |   |   |   |   |   |   |   |--- value: [33.80]
# |   |   |   |   |   |   |   |--- feature_5 >  7.27
# |   |   |   |   |   |   |   |   |--- feature_5 <= 7.34
# |   |   |   |   |   |   |   |   |   |--- value: [31.00]
# |   |   |   |   |   |   |   |   |--- feature_5 >  7.34
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 4.99
# |   |   |   |   |   |   |   |   |   |   |--- value: [31.50]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  4.99
# |   |   |   |   |   |   |   |   |   |   |--- value: [31.70]
# |   |   |--- feature_4 >  0.66
# |   |   |   |--- feature_5 <= 7.14
# |   |   |   |   |--- value: [10.40]
# |   |   |   |--- feature_5 >  7.14
# |   |   |   |   |--- feature_12 <= 15.09
# |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |--- feature_12 >  15.09
# |   |   |   |   |   |--- value: [17.80]
# |   |--- feature_5 >  7.44
# |   |   |--- feature_0 <= 2.74
# |   |   |   |--- feature_10 <= 14.80
# |   |   |   |   |--- feature_5 <= 7.71
# |   |   |   |   |   |--- feature_7 <= 2.06
# |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |   |   |--- feature_7 >  2.06
# |   |   |   |   |   |   |--- feature_10 <= 13.85
# |   |   |   |   |   |   |   |--- feature_12 <= 5.21
# |   |   |   |   |   |   |   |   |--- value: [43.50]
# |   |   |   |   |   |   |   |--- feature_12 >  5.21
# |   |   |   |   |   |   |   |   |--- value: [43.10]
# |   |   |   |   |   |   |--- feature_10 >  13.85
# |   |   |   |   |   |   |   |--- value: [42.30]
# |   |   |   |   |--- feature_5 >  7.71
# |   |   |   |   |   |--- feature_12 <= 3.75
# |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |   |   |--- feature_12 >  3.75
# |   |   |   |   |   |   |--- feature_0 <= 0.55
# |   |   |   |   |   |   |   |--- feature_12 <= 4.86
# |   |   |   |   |   |   |   |   |--- value: [48.50]
# |   |   |   |   |   |   |   |--- feature_12 >  4.86
# |   |   |   |   |   |   |   |   |--- value: [48.80]
# |   |   |   |   |   |   |--- feature_0 >  0.55
# |   |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |--- feature_10 >  14.80
# |   |   |   |   |--- feature_11 <= 385.48
# |   |   |   |   |   |--- feature_0 <= 0.32
# |   |   |   |   |   |   |--- feature_0 <= 0.31
# |   |   |   |   |   |   |   |--- feature_8 <= 6.50
# |   |   |   |   |   |   |   |   |--- value: [46.00]
# |   |   |   |   |   |   |   |--- feature_8 >  6.50
# |   |   |   |   |   |   |   |   |--- value: [46.70]
# |   |   |   |   |   |   |--- feature_0 >  0.31
# |   |   |   |   |   |   |   |--- value: [44.80]
# |   |   |   |   |   |--- feature_0 >  0.32
# |   |   |   |   |   |   |--- feature_7 <= 3.27
# |   |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |   |   |   |--- feature_7 >  3.27
# |   |   |   |   |   |   |   |--- value: [48.30]
# |   |   |   |   |--- feature_11 >  385.48
# |   |   |   |   |   |--- feature_0 <= 0.06
# |   |   |   |   |   |   |--- feature_0 <= 0.05
# |   |   |   |   |   |   |   |--- feature_10 <= 15.40
# |   |   |   |   |   |   |   |   |--- value: [45.40]
# |   |   |   |   |   |   |   |--- feature_10 >  15.40
# |   |   |   |   |   |   |   |   |--- value: [44.00]
# |   |   |   |   |   |   |--- feature_0 >  0.05
# |   |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |   |   |--- feature_0 >  0.06
# |   |   |   |   |   |   |--- feature_6 <= 44.35
# |   |   |   |   |   |   |   |--- feature_10 <= 18.55
# |   |   |   |   |   |   |   |   |--- value: [43.80]
# |   |   |   |   |   |   |   |--- feature_10 >  18.55
# |   |   |   |   |   |   |   |   |--- value: [42.80]
# |   |   |   |   |   |   |--- feature_6 >  44.35
# |   |   |   |   |   |   |   |--- feature_6 <= 62.55
# |   |   |   |   |   |   |   |   |--- value: [35.20]
# |   |   |   |   |   |   |   |--- feature_6 >  62.55
# |   |   |   |   |   |   |   |   |--- feature_11 <= 386.65
# |   |   |   |   |   |   |   |   |   |--- value: [41.70]
# |   |   |   |   |   |   |   |   |--- feature_11 >  386.65
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- value: [39.80]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 5.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [38.70]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  5.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [37.60]
# |   |   |--- feature_0 >  2.74
# |   |   |   |--- value: [21.90]

# %% [markdown]
# ##### plot_tree를 사용한 시각화

# %%
tree.plot_tree(model)
# Out:
# [Text(0.6833210281732908, 0.975, 'X[5] <= 6.941\nsquared_error = 84.42\nsamples = 506\nvalue = 22.533'),
#  Text(0.43066394817519316, 0.925, 'X[12] <= 14.4\nsquared_error = 40.273\nsamples = 430\nvalue = 19.934'),
#  Text(0.19563192351030204, 0.875, 'X[7] <= 1.385\nsquared_error = 26.009\nsamples = 255\nvalue = 23.35'),
#  Text(0.11327759160618123, 0.825, 'X[12] <= 10.83\nsquared_error = 78.146\nsamples = 5\nvalue = 45.58'),
#  Text(0.11140449397096698, 0.775, 'squared_error = 0.0\nsamples = 4\nvalue = 50.0'),
#  Text(0.11515068924139546, 0.775, 'squared_error = -0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.27798625541442284, 0.825, 'X[5] <= 6.543\nsquared_error = 14.885\nsamples = 250\nvalue = 22.905'),
#  Text(0.11889688451182392, 0.775, 'X[12] <= 7.57\nsquared_error = 8.39\nsamples = 195\nvalue = 21.63'),
#  Text(0.04141301802856474, 0.725, 'X[9] <= 222.5\nsquared_error = 3.015\nsamples = 43\nvalue = 23.97'),
#  Text(0.039539920393350504, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 28.7'),
#  Text(0.043286115663778976, 0.675, 'X[2] <= 5.48\nsquared_error = 2.541\nsamples = 42\nvalue = 23.857'),
#  Text(0.02973542495902599, 0.625, 'X[10] <= 19.95\nsquared_error = 1.328\nsamples = 19\nvalue = 23.011'),
#  Text(0.018262701943338795, 0.575, 'X[11] <= 393.33\nsquared_error = 0.72\nsamples = 16\nvalue = 23.356'),
#  Text(0.007492390540856942, 0.525, 'X[2] <= 3.895\nsquared_error = 0.337\nsamples = 8\nvalue = 22.962'),
#  Text(0.003746195270428471, 0.475, 'X[4] <= 0.396\nsquared_error = 0.096\nsamples = 3\nvalue = 22.333'),
#  Text(0.0018730976352142356, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 21.9'),
#  Text(0.005619292905642706, 0.425, 'X[5] <= 6.339\nsquared_error = 0.002\nsamples = 2\nvalue = 22.55'),
#  Text(0.003746195270428471, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.007492390540856942, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.011238585811285413, 0.475, 'X[6] <= 23.1\nsquared_error = 0.102\nsamples = 5\nvalue = 23.34'),
#  Text(0.009365488176071178, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 23.7'),
#  Text(0.013111683446499649, 0.425, 'X[9] <= 282.5\nsquared_error = 0.027\nsamples = 3\nvalue = 23.1'),
#  Text(0.011238585811285413, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.014984781081713885, 0.375, 'X[4] <= 0.441\nsquared_error = 0.01\nsamples = 2\nvalue = 23.2'),
#  Text(0.013111683446499649, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.01685787871692812, 0.325, 'squared_error = -0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.02903301334582065, 0.525, 'X[5] <= 6.419\nsquared_error = 0.792\nsamples = 8\nvalue = 23.75'),
#  Text(0.02435026925778506, 0.475, 'X[4] <= 0.407\nsquared_error = 0.376\nsamples = 6\nvalue = 24.15'),
#  Text(0.02060407398735659, 0.425, 'X[0] <= 0.037\nsquared_error = 0.022\nsamples = 2\nvalue = 23.35'),
#  Text(0.018730976352142357, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 23.5'),
#  Text(0.022477171622570825, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 23.2'),
#  Text(0.028096464528213533, 0.425, 'X[11] <= 394.685\nsquared_error = 0.072\nsamples = 4\nvalue = 24.55'),
#  Text(0.026223366892999297, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 24.1'),
#  Text(0.02996956216342777, 0.375, 'X[6] <= 33.95\nsquared_error = 0.007\nsamples = 3\nvalue = 24.7'),
#  Text(0.028096464528213533, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.031842659798642, 0.325, 'X[1] <= 42.5\nsquared_error = 0.002\nsamples = 2\nvalue = 24.65'),
#  Text(0.02996956216342777, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.6'),
#  Text(0.03371575743385624, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.03371575743385624, 0.475, 'X[0] <= 0.086\nsquared_error = 0.123\nsamples = 2\nvalue = 22.55'),
#  Text(0.031842659798642, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.035588855069070474, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.04120814797471318, 0.575, 'X[5] <= 6.313\nsquared_error = 0.536\nsamples = 3\nvalue = 21.167'),
#  Text(0.039335050339498946, 0.525, 'X[11] <= 382.72\nsquared_error = 0.003\nsamples = 2\nvalue = 20.65'),
#  Text(0.037461952704284714, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.04120814797471318, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 20.7'),
#  Text(0.04308124560992742, 0.525, 'squared_error = -0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.05683680636853196, 0.625, 'X[1] <= 34.0\nsquared_error = 2.462\nsamples = 23\nvalue = 24.557'),
#  Text(0.054963708733317726, 0.575, 'X[11] <= 359.505\nsquared_error = 1.593\nsamples = 22\nvalue = 24.35'),
#  Text(0.04682744088035589, 0.525, 'X[6] <= 96.3\nsquared_error = 1.976\nsamples = 3\nvalue = 26.267'),
#  Text(0.04495434324514165, 0.475, 'X[2] <= 18.84\nsquared_error = 0.062\nsamples = 2\nvalue = 27.25'),
#  Text(0.04308124560992742, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 27.5'),
#  Text(0.04682744088035589, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.04870053851557012, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.06309997658627955, 0.525, 'X[5] <= 6.146\nsquared_error = 0.86\nsamples = 19\nvalue = 24.047'),
#  Text(0.052446733785998595, 0.475, 'X[9] <= 304.5\nsquared_error = 0.176\nsamples = 3\nvalue = 22.667'),
#  Text(0.05057363615078436, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 22.1'),
#  Text(0.05431983142121283, 0.425, 'X[9] <= 306.0\nsquared_error = 0.023\nsamples = 2\nvalue = 22.95'),
#  Text(0.052446733785998595, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.05619292905642707, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.07375321938656053, 0.475, 'X[9] <= 278.5\nsquared_error = 0.564\nsamples = 16\nvalue = 24.306'),
#  Text(0.06181222196206977, 0.425, 'X[6] <= 6.55\nsquared_error = 0.042\nsamples = 5\nvalue = 25.04'),
#  Text(0.05993912432685554, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.063685319597284, 0.375, 'X[0] <= 0.098\nsquared_error = 0.017\nsamples = 4\nvalue = 25.125'),
#  Text(0.06181222196206977, 0.325, 'squared_error = 0.0\nsamples = 2\nvalue = 25.0'),
#  Text(0.06555841723249825, 0.325, 'X[4] <= 0.456\nsquared_error = 0.003\nsamples = 2\nvalue = 25.25'),
#  Text(0.063685319597284, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(0.06743151486771248, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 25.2'),
#  Text(0.08569421681105127, 0.425, 'X[12] <= 6.135\nsquared_error = 0.446\nsamples = 11\nvalue = 23.973'),
#  Text(0.07679700304378366, 0.375, 'X[0] <= 0.203\nsquared_error = 0.05\nsamples = 4\nvalue = 24.7'),
#  Text(0.07305080777335518, 0.325, 'X[9] <= 308.5\nsquared_error = 0.01\nsamples = 2\nvalue = 24.5'),
#  Text(0.07117771013814095, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.6'),
#  Text(0.07492390540856943, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.08054319831421212, 0.325, 'X[9] <= 308.5\nsquared_error = 0.01\nsamples = 2\nvalue = 24.9'),
#  Text(0.07867010067899789, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.08241629594942636, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.0945914305783189, 0.375, 'X[0] <= 0.175\nsquared_error = 0.197\nsamples = 7\nvalue = 23.557'),
#  Text(0.08803558885506907, 0.325, 'X[9] <= 296.0\nsquared_error = 0.029\nsamples = 3\nvalue = 24.033'),
#  Text(0.08616249121985484, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.0899086864902833, 0.275, 'X[0] <= 0.084\nsquared_error = 0.002\nsamples = 2\nvalue = 24.15'),
#  Text(0.08803558885506907, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 24.1'),
#  Text(0.09178178412549755, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 24.2'),
#  Text(0.10114727230156872, 0.325, 'X[10] <= 19.4\nsquared_error = 0.025\nsamples = 4\nvalue = 23.2'),
#  Text(0.09740107703114025, 0.275, 'X[2] <= 15.195\nsquared_error = 0.002\nsamples = 2\nvalue = 23.35'),
#  Text(0.09552797939592601, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 23.4'),
#  Text(0.09927417466635448, 0.225, 'squared_error = -0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.10489346757199719, 0.275, 'X[6] <= 41.6\nsquared_error = 0.002\nsamples = 2\nvalue = 23.05'),
#  Text(0.10302036993678296, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.10676656520721142, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.0587099040037462, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 29.1'),
#  Text(0.19638075099508312, 0.725, 'X[9] <= 208.0\nsquared_error = 7.924\nsamples = 152\nvalue = 20.968'),
#  Text(0.12912666822758137, 0.675, 'X[5] <= 6.074\nsquared_error = 32.32\nsamples = 5\nvalue = 26.9'),
#  Text(0.1253804729571529, 0.625, 'X[8] <= 2.5\nsquared_error = 6.607\nsamples = 3\nvalue = 22.9'),
#  Text(0.12350737532193866, 0.575, 'X[0] <= 0.07\nsquared_error = 0.722\nsamples = 2\nvalue = 21.15'),
#  Text(0.12163427768672443, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.1253804729571529, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.12725357059236714, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 26.4'),
#  Text(0.13287286349800984, 0.625, 'X[12] <= 11.3\nsquared_error = 10.89\nsamples = 2\nvalue = 32.9'),
#  Text(0.1309997658627956, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 36.2'),
#  Text(0.13474596113322407, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.2636348337625849, 0.675, 'X[5] <= 6.078\nsquared_error = 5.856\nsamples = 147\nvalue = 20.766'),
#  Text(0.2050383399672208, 0.625, 'X[6] <= 69.1\nsquared_error = 5.537\nsamples = 79\nvalue = 19.997'),
#  Text(0.15679875907281668, 0.575, 'X[7] <= 4.464\nsquared_error = 3.664\nsamples = 55\nvalue = 20.513'),
#  Text(0.12912666822758137, 0.525, 'X[5] <= 5.214\nsquared_error = 3.847\nsamples = 23\nvalue = 21.465'),
#  Text(0.12725357059236714, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 16.1'),
#  Text(0.1309997658627956, 0.475, 'X[10] <= 17.6\nsquared_error = 2.654\nsamples = 22\nvalue = 21.709'),
#  Text(0.1161320533832826, 0.425, 'X[7] <= 3.613\nsquared_error = 0.346\nsamples = 5\nvalue = 23.24'),
#  Text(0.11425895574806837, 0.375, 'X[0] <= 0.077\nsquared_error = 0.082\nsamples = 4\nvalue = 22.975'),
#  Text(0.1105127604776399, 0.325, 'X[2] <= 8.97\nsquared_error = 0.003\nsamples = 2\nvalue = 23.25'),
#  Text(0.10863966284242565, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 23.2'),
#  Text(0.11238585811285413, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.11800515101849685, 0.325, 'X[10] <= 14.8\nsquared_error = 0.01\nsamples = 2\nvalue = 22.7'),
#  Text(0.1161320533832826, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.11987824865371108, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.11800515101849685, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.1458674783423086, 0.425, 'X[6] <= 46.65\nsquared_error = 2.441\nsamples = 17\nvalue = 21.259'),
#  Text(0.13486302973542497, 0.375, 'X[5] <= 5.881\nsquared_error = 2.343\nsamples = 9\nvalue = 22.111'),
#  Text(0.127370639194568, 0.325, 'X[11] <= 379.69\nsquared_error = 0.286\nsamples = 5\nvalue = 20.94'),
#  Text(0.12362444392413954, 0.275, 'X[2] <= 13.12\nsquared_error = 0.04\nsamples = 2\nvalue = 20.4'),
#  Text(0.12175134628892531, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 20.2'),
#  Text(0.12549754155935378, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.1311168344649965, 0.275, 'X[5] <= 5.806\nsquared_error = 0.127\nsamples = 3\nvalue = 21.3'),
#  Text(0.12924373682978224, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 21.8'),
#  Text(0.13298993210021073, 0.225, 'X[0] <= 0.19\nsquared_error = 0.002\nsamples = 2\nvalue = 21.05'),
#  Text(0.1311168344649965, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.13486302973542497, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 21.1'),
#  Text(0.1423554202762819, 0.325, 'X[9] <= 278.0\nsquared_error = 1.057\nsamples = 4\nvalue = 23.575'),
#  Text(0.13860922500585343, 0.275, 'X[4] <= 0.469\nsquared_error = 0.002\nsamples = 2\nvalue = 22.55'),
#  Text(0.1367361273706392, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.14048232264106766, 0.225, 'squared_error = -0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.14610161554671036, 0.275, 'X[7] <= 3.115\nsquared_error = 0.01\nsamples = 2\nvalue = 24.6'),
#  Text(0.14422851791149613, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.1479747131819246, 0.225, 'squared_error = -0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.15687192694919222, 0.375, 'X[7] <= 2.584\nsquared_error = 0.815\nsamples = 8\nvalue = 20.3'),
#  Text(0.1517209084523531, 0.325, 'X[5] <= 5.863\nsquared_error = 0.09\nsamples = 2\nvalue = 21.5'),
#  Text(0.14984781081713885, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 21.8'),
#  Text(0.15359400608756732, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.16202294544603138, 0.325, 'X[6] <= 63.35\nsquared_error = 0.417\nsamples = 6\nvalue = 19.9'),
#  Text(0.15734020135799578, 0.275, 'X[5] <= 5.873\nsquared_error = 0.125\nsamples = 4\nvalue = 20.3'),
#  Text(0.15359400608756732, 0.225, 'X[7] <= 3.222\nsquared_error = 0.002\nsamples = 2\nvalue = 19.95'),
#  Text(0.1517209084523531, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.9'),
#  Text(0.15546710372278155, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(0.16108639662842425, 0.225, 'X[2] <= 12.53\nsquared_error = 0.002\nsamples = 2\nvalue = 20.65'),
#  Text(0.15921329899321002, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.7'),
#  Text(0.16295949426363848, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.16670568953406698, 0.275, 'X[5] <= 5.832\nsquared_error = 0.04\nsamples = 2\nvalue = 19.1'),
#  Text(0.16483259189885272, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.1685787871692812, 0.225, 'squared_error = -0.0\nsamples = 1\nvalue = 18.9'),
#  Text(0.184470849918052, 0.525, 'X[5] <= 5.763\nsquared_error = 2.411\nsamples = 32\nvalue = 19.828'),
#  Text(0.1685787871692812, 0.475, 'X[9] <= 294.0\nsquared_error = 0.658\nsamples = 5\nvalue = 18.14'),
#  Text(0.16483259189885272, 0.425, 'X[1] <= 12.5\nsquared_error = 0.09\nsamples = 2\nvalue = 19.0'),
#  Text(0.16295949426363848, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.16670568953406698, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.17232498243970967, 0.425, 'X[10] <= 20.45\nsquared_error = 0.216\nsamples = 3\nvalue = 17.567'),
#  Text(0.17045188480449544, 0.375, 'X[6] <= 32.6\nsquared_error = 0.022\nsamples = 2\nvalue = 17.25'),
#  Text(0.1685787871692812, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 17.1'),
#  Text(0.17232498243970967, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(0.1741980800749239, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 18.2'),
#  Text(0.20036291266682277, 0.475, 'X[2] <= 5.415\nsquared_error = 2.11\nsamples = 27\nvalue = 20.141'),
#  Text(0.18730976352142356, 0.425, 'X[6] <= 47.85\nsquared_error = 1.291\nsamples = 13\nvalue = 19.223'),
#  Text(0.1798173729805666, 0.375, 'X[0] <= 0.042\nsquared_error = 0.684\nsamples = 9\nvalue = 19.778'),
#  Text(0.17607117771013814, 0.325, 'X[12] <= 9.525\nsquared_error = 0.382\nsamples = 4\nvalue = 20.525'),
#  Text(0.1741980800749239, 0.275, 'X[7] <= 5.399\nsquared_error = 0.042\nsamples = 3\nvalue = 20.867'),
#  Text(0.17232498243970967, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.17607117771013814, 0.225, 'X[10] <= 18.3\nsquared_error = 0.01\nsamples = 2\nvalue = 21.0'),
#  Text(0.1741980800749239, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.17794427534535237, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 21.1'),
#  Text(0.17794427534535237, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 19.5'),
#  Text(0.1835635682509951, 0.325, 'X[6] <= 22.15\nsquared_error = 0.122\nsamples = 5\nvalue = 19.18'),
#  Text(0.18169047061578084, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(0.18543666588620933, 0.275, 'X[4] <= 0.487\nsquared_error = 0.047\nsamples = 4\nvalue = 19.325'),
#  Text(0.1835635682509951, 0.225, 'X[9] <= 310.5\nsquared_error = 0.016\nsamples = 3\nvalue = 19.433'),
#  Text(0.18169047061578084, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.18543666588620933, 0.175, 'X[1] <= 40.0\nsquared_error = 0.002\nsamples = 2\nvalue = 19.35'),
#  Text(0.1835635682509951, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.18730976352142356, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 19.4'),
#  Text(0.18730976352142356, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.0'),
#  Text(0.1948021540622805, 0.375, 'X[10] <= 19.5\nsquared_error = 0.407\nsamples = 4\nvalue = 17.975'),
#  Text(0.19105595879185203, 0.325, 'X[5] <= 5.956\nsquared_error = 0.022\nsamples = 2\nvalue = 17.35'),
#  Text(0.1891828611566378, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 17.2'),
#  Text(0.19292905642706626, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 17.5'),
#  Text(0.19854834933270896, 0.325, 'X[0] <= 0.046\nsquared_error = 0.01\nsamples = 2\nvalue = 18.6'),
#  Text(0.19667525169749472, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.2004214469679232, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.21341606181222197, 0.425, 'X[6] <= 22.35\nsquared_error = 1.362\nsamples = 14\nvalue = 20.993'),
#  Text(0.20791383750878015, 0.375, 'X[7] <= 6.656\nsquared_error = 0.549\nsamples = 3\nvalue = 22.367'),
#  Text(0.20604073987356591, 0.325, 'X[6] <= 19.45\nsquared_error = 0.023\nsamples = 2\nvalue = 21.85'),
#  Text(0.20416764223835168, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.20791383750878015, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.20978693514399438, 0.325, 'squared_error = -0.0\nsamples = 1\nvalue = 23.4'),
#  Text(0.21891828611566377, 0.375, 'X[10] <= 16.4\nsquared_error = 0.929\nsamples = 11\nvalue = 20.618'),
#  Text(0.21353313041442284, 0.325, 'X[6] <= 54.45\nsquared_error = 0.36\nsamples = 2\nvalue = 22.3'),
#  Text(0.2116600327792086, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.21540622804963708, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.2243034418169047, 0.325, 'X[1] <= 16.75\nsquared_error = 0.287\nsamples = 9\nvalue = 20.244'),
#  Text(0.21915242332006557, 0.275, 'X[7] <= 5.411\nsquared_error = 0.185\nsamples = 7\nvalue = 20.443'),
#  Text(0.21446967923202997, 0.225, 'X[5] <= 5.854\nsquared_error = 0.044\nsamples = 5\nvalue = 20.2'),
#  Text(0.2107234839616015, 0.175, 'X[5] <= 5.81\nsquared_error = 0.002\nsamples = 2\nvalue = 19.95'),
#  Text(0.20885038632638725, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(0.21259658159681574, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 19.9'),
#  Text(0.21821587450245844, 0.175, 'X[0] <= 0.218\nsquared_error = 0.002\nsamples = 3\nvalue = 20.367'),
#  Text(0.2163427768672442, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.22008897213767267, 0.125, 'squared_error = -0.0\nsamples = 2\nvalue = 20.4'),
#  Text(0.22383516740810114, 0.225, 'X[8] <= 3.5\nsquared_error = 0.022\nsamples = 2\nvalue = 21.05'),
#  Text(0.2219620697728869, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.22570826504331537, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.22945446031374386, 0.275, 'X[11] <= 378.905\nsquared_error = 0.023\nsamples = 2\nvalue = 19.55'),
#  Text(0.22758136267852963, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.4'),
#  Text(0.2313275579489581, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.7'),
#  Text(0.25327792086162493, 0.575, 'X[5] <= 6.029\nsquared_error = 7.826\nsamples = 24\nvalue = 18.817'),
#  Text(0.24361976118005152, 0.525, 'X[4] <= 0.601\nsquared_error = 5.256\nsamples = 22\nvalue = 19.327'),
#  Text(0.2299227347225474, 0.475, 'X[7] <= 2.623\nsquared_error = 2.162\nsamples = 12\nvalue = 18.167'),
#  Text(0.2245375790213065, 0.425, 'X[7] <= 1.956\nsquared_error = 0.81\nsamples = 2\nvalue = 15.9'),
#  Text(0.22266448138609224, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.22641067665652073, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 16.8'),
#  Text(0.23530789042378833, 0.425, 'X[5] <= 5.707\nsquared_error = 1.2\nsamples = 10\nvalue = 18.62'),
#  Text(0.2301568719269492, 0.375, 'X[9] <= 317.0\nsquared_error = 0.49\nsamples = 2\nvalue = 16.9'),
#  Text(0.22828377429173496, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 16.2'),
#  Text(0.23202996956216343, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 17.6'),
#  Text(0.2404589089206275, 0.375, 'X[6] <= 75.5\nsquared_error = 0.452\nsamples = 8\nvalue = 19.05'),
#  Text(0.2357761648325919, 0.325, 'X[9] <= 297.0\nsquared_error = 0.016\nsamples = 3\nvalue = 18.333'),
#  Text(0.23390306719737766, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.23764926246780613, 0.275, 'X[10] <= 20.1\nsquared_error = 0.003\nsamples = 2\nvalue = 18.25'),
#  Text(0.2357761648325919, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.23952236010302036, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 18.2'),
#  Text(0.24514165300866309, 0.325, 'X[12] <= 10.135\nsquared_error = 0.222\nsamples = 5\nvalue = 19.48'),
#  Text(0.24326855537344885, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.24701475064387732, 0.275, 'X[10] <= 18.1\nsquared_error = 0.067\nsamples = 4\nvalue = 19.275'),
#  Text(0.24326855537344885, 0.225, 'X[6] <= 82.75\nsquared_error = 0.023\nsamples = 2\nvalue = 19.05'),
#  Text(0.2413954577382346, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.2'),
#  Text(0.24514165300866309, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 18.9'),
#  Text(0.2507609459143058, 0.225, 'X[4] <= 0.541\nsquared_error = 0.01\nsamples = 2\nvalue = 19.5'),
#  Text(0.24888784827909155, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.25263404354952, 0.175, 'squared_error = -0.0\nsamples = 1\nvalue = 19.4'),
#  Text(0.2573167876375556, 0.475, 'X[3] <= 0.5\nsquared_error = 5.412\nsamples = 10\nvalue = 20.72'),
#  Text(0.25544369000234135, 0.425, 'X[11] <= 259.58\nsquared_error = 2.386\nsamples = 9\nvalue = 21.322'),
#  Text(0.2507609459143058, 0.375, 'X[9] <= 534.5\nsquared_error = 0.122\nsamples = 2\nvalue = 23.45'),
#  Text(0.24888784827909155, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.25263404354952, 0.325, 'squared_error = -0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.26012643409037695, 0.375, 'X[6] <= 96.75\nsquared_error = 1.37\nsamples = 7\nvalue = 20.714'),
#  Text(0.2563802388199485, 0.325, 'X[4] <= 0.607\nsquared_error = 0.85\nsamples = 5\nvalue = 21.26'),
#  Text(0.2545071411847343, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.25825333645516274, 0.275, 'X[5] <= 5.162\nsquared_error = 0.415\nsamples = 4\nvalue = 20.9'),
#  Text(0.2563802388199485, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 21.9'),
#  Text(0.26012643409037695, 0.225, 'X[4] <= 0.612\nsquared_error = 0.109\nsamples = 3\nvalue = 20.567'),
#  Text(0.25825333645516274, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.2619995317255912, 0.175, 'X[11] <= 336.17\nsquared_error = 0.0\nsamples = 2\nvalue = 20.8'),
#  Text(0.26012643409037695, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.2638726293608054, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.2638726293608054, 0.325, 'X[6] <= 98.65\nsquared_error = 0.063\nsamples = 2\nvalue = 19.35'),
#  Text(0.2619995317255912, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 19.1'),
#  Text(0.26574572699601967, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.2591898852727698, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 15.3'),
#  Text(0.26293608054319834, 0.525, 'X[0] <= 0.701\nsquared_error = 1.69\nsamples = 2\nvalue = 13.2'),
#  Text(0.2610629829079841, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.26480917817841254, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 14.5'),
#  Text(0.322231327557949, 0.625, 'X[12] <= 9.98\nsquared_error = 4.744\nsamples = 68\nvalue = 21.659'),
#  Text(0.28295481151955043, 0.575, 'X[0] <= 0.046\nsquared_error = 5.482\nsamples = 24\nvalue = 22.921'),
#  Text(0.2713650199016624, 0.525, 'X[2] <= 2.07\nsquared_error = 3.299\nsamples = 9\nvalue = 20.911'),
#  Text(0.26949192226644814, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.2732381175368766, 0.475, 'X[5] <= 6.23\nsquared_error = 0.975\nsamples = 8\nvalue = 21.463'),
#  Text(0.2676188246312339, 0.425, 'X[11] <= 381.27\nsquared_error = 0.127\nsamples = 3\nvalue = 20.3'),
#  Text(0.26574572699601967, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 19.8'),
#  Text(0.26949192226644814, 0.375, 'X[10] <= 18.9\nsquared_error = 0.002\nsamples = 2\nvalue = 20.55'),
#  Text(0.2676188246312339, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 20.5'),
#  Text(0.2713650199016624, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.2788574104425193, 0.425, 'X[10] <= 18.0\nsquared_error = 0.186\nsamples = 5\nvalue = 22.16'),
#  Text(0.27698431280730507, 0.375, 'X[9] <= 256.0\nsquared_error = 0.062\nsamples = 4\nvalue = 21.975'),
#  Text(0.27511121517209086, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 21.6'),
#  Text(0.2788574104425193, 0.325, 'X[11] <= 395.81\nsquared_error = 0.02\nsamples = 3\nvalue = 22.1'),
#  Text(0.27698431280730507, 0.275, 'squared_error = 0.0\nsamples = 2\nvalue = 22.0'),
#  Text(0.28073050807773353, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.3'),
#  Text(0.28073050807773353, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.2945446031374385, 0.525, 'X[6] <= 33.6\nsquared_error = 2.915\nsamples = 15\nvalue = 24.127'),
#  Text(0.284476703348162, 0.475, 'X[12] <= 8.625\nsquared_error = 2.976\nsamples = 3\nvalue = 26.133'),
#  Text(0.2826036057129478, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.28634980098337626, 0.425, 'X[7] <= 4.719\nsquared_error = 0.722\nsamples = 2\nvalue = 27.25'),
#  Text(0.284476703348162, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 28.1'),
#  Text(0.2882228986185905, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 26.4'),
#  Text(0.30461250292671505, 0.475, 'X[12] <= 9.1\nsquared_error = 1.642\nsamples = 12\nvalue = 23.625'),
#  Text(0.2966518379770546, 0.425, 'X[12] <= 7.845\nsquared_error = 1.662\nsamples = 7\nvalue = 22.971'),
#  Text(0.291969093889019, 0.375, 'X[5] <= 6.468\nsquared_error = 0.09\nsamples = 2\nvalue = 24.7'),
#  Text(0.2900959962538047, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.2938421915242332, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.3013345820650901, 0.375, 'X[7] <= 3.178\nsquared_error = 0.618\nsamples = 5\nvalue = 22.28'),
#  Text(0.29758838679466165, 0.325, 'X[9] <= 283.0\nsquared_error = 0.25\nsamples = 2\nvalue = 23.1'),
#  Text(0.29571528915944745, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.2994614844298759, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.30508077733551864, 0.325, 'X[8] <= 3.5\nsquared_error = 0.116\nsamples = 3\nvalue = 21.733'),
#  Text(0.3032076797003044, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.30695387497073284, 0.275, 'X[7] <= 3.883\nsquared_error = 0.01\nsamples = 2\nvalue = 21.5'),
#  Text(0.30508077733551864, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 21.6'),
#  Text(0.3088269726059471, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.31257316787637557, 0.425, 'X[2] <= 8.225\nsquared_error = 0.178\nsamples = 5\nvalue = 24.54'),
#  Text(0.3107000702411613, 0.375, 'X[7] <= 6.303\nsquared_error = 0.062\nsamples = 3\nvalue = 24.233'),
#  Text(0.3088269726059471, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.31257316787637557, 0.325, 'X[0] <= 0.252\nsquared_error = 0.01\nsamples = 2\nvalue = 24.4'),
#  Text(0.3107000702411613, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.3144462655115898, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.3144462655115898, 0.375, 'squared_error = -0.0\nsamples = 2\nvalue = 25.0'),
#  Text(0.36150784359634747, 0.575, 'X[11] <= 197.52\nsquared_error = 2.998\nsamples = 44\nvalue = 20.97'),
#  Text(0.34909857176305314, 0.525, 'X[12] <= 11.33\nsquared_error = 1.562\nsamples = 2\nvalue = 17.35'),
#  Text(0.34722547412783894, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(0.3509716693982674, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 16.1'),
#  Text(0.3739171154296418, 0.525, 'X[10] <= 20.55\nsquared_error = 2.412\nsamples = 42\nvalue = 21.143'),
#  Text(0.35471786466869587, 0.475, 'X[5] <= 6.318\nsquared_error = 2.003\nsamples = 32\nvalue = 21.509'),
#  Text(0.3383282603605713, 0.425, 'X[5] <= 6.246\nsquared_error = 1.539\nsamples = 23\nvalue = 21.061'),
#  Text(0.3266214001404823, 0.375, 'X[5] <= 6.09\nsquared_error = 1.24\nsamples = 17\nvalue = 21.453'),
#  Text(0.3200655584172325, 0.325, 'X[10] <= 18.5\nsquared_error = 0.81\nsamples = 2\nvalue = 23.1'),
#  Text(0.31819246078201824, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.0'),
#  Text(0.32193865605244676, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.33317724186373215, 0.325, 'X[0] <= 4.15\nsquared_error = 0.888\nsamples = 15\nvalue = 21.233'),
#  Text(0.3256848513228752, 0.275, 'X[8] <= 15.5\nsquared_error = 0.368\nsamples = 10\nvalue = 20.74'),
#  Text(0.32381175368766096, 0.225, 'X[4] <= 0.434\nsquared_error = 0.249\nsamples = 9\nvalue = 20.867'),
#  Text(0.31819246078201824, 0.175, 'X[0] <= 0.151\nsquared_error = 0.036\nsamples = 3\nvalue = 20.233'),
#  Text(0.31631936314680403, 0.125, 'squared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(0.3200655584172325, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 20.5'),
#  Text(0.3294310465933037, 0.175, 'X[6] <= 64.2\nsquared_error = 0.055\nsamples = 6\nvalue = 21.183'),
#  Text(0.32381175368766096, 0.125, 'X[6] <= 49.75\nsquared_error = 0.027\nsamples = 3\nvalue = 21.0'),
#  Text(0.32193865605244676, 0.075, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.3256848513228752, 0.075, 'X[0] <= 0.266\nsquared_error = 0.01\nsamples = 2\nvalue = 21.1'),
#  Text(0.32381175368766096, 0.025, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.32755794895808943, 0.025, 'squared_error = -0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.33505033949894636, 0.125, 'X[5] <= 6.17\nsquared_error = 0.016\nsamples = 3\nvalue = 21.367'),
#  Text(0.33317724186373215, 0.075, 'X[8] <= 3.5\nsquared_error = 0.003\nsamples = 2\nvalue = 21.45'),
#  Text(0.3313041442285179, 0.025, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.33505033949894636, 0.025, 'squared_error = 0.0\nsamples = 1\nvalue = 21.5'),
#  Text(0.3369234371341606, 0.075, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.32755794895808943, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.3406696324045891, 0.275, 'X[12] <= 12.89\nsquared_error = 0.466\nsamples = 5\nvalue = 22.22'),
#  Text(0.3387965347693749, 0.225, 'X[6] <= 73.0\nsquared_error = 0.029\nsamples = 3\nvalue = 22.767'),
#  Text(0.3369234371341606, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.3406696324045891, 0.175, 'X[0] <= 4.732\nsquared_error = 0.003\nsamples = 2\nvalue = 22.65'),
#  Text(0.3387965347693749, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.34254273003980334, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.34254273003980334, 0.225, 'squared_error = -0.0\nsamples = 2\nvalue = 21.4'),
#  Text(0.3500351205806603, 0.375, 'X[7] <= 3.175\nsquared_error = 0.716\nsamples = 6\nvalue = 19.95'),
#  Text(0.3462889253102318, 0.325, 'X[2] <= 14.055\nsquared_error = 0.347\nsamples = 3\nvalue = 19.3'),
#  Text(0.34441582767501755, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.348162022945446, 0.275, 'X[11] <= 373.775\nsquared_error = 0.04\nsamples = 2\nvalue = 19.7'),
#  Text(0.3462889253102318, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.9'),
#  Text(0.3500351205806603, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.5'),
#  Text(0.35378131585108874, 0.325, 'X[2] <= 13.935\nsquared_error = 0.24\nsamples = 3\nvalue = 20.6'),
#  Text(0.3519082182158745, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(0.355654413486303, 0.275, 'X[4] <= 0.523\nsquared_error = 0.09\nsamples = 2\nvalue = 20.9'),
#  Text(0.35378131585108874, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.3575275111215172, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.3711074689768204, 0.425, 'X[4] <= 0.659\nsquared_error = 1.36\nsamples = 9\nvalue = 22.656'),
#  Text(0.36595645047998127, 0.375, 'X[5] <= 6.342\nsquared_error = 0.52\nsamples = 7\nvalue = 23.143'),
#  Text(0.36127370639194567, 0.325, 'X[5] <= 6.322\nsquared_error = 0.09\nsamples = 2\nvalue = 24.1'),
#  Text(0.35940060875673147, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.36314680402715993, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.37063919456801686, 0.325, 'X[11] <= 383.06\nsquared_error = 0.178\nsamples = 5\nvalue = 22.76'),
#  Text(0.3668929992975884, 0.275, 'X[0] <= 1.276\nsquared_error = 0.002\nsamples = 2\nvalue = 22.25'),
#  Text(0.36501990166237414, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.3687660969328026, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 22.3'),
#  Text(0.3743853898384453, 0.275, 'X[11] <= 393.555\nsquared_error = 0.007\nsamples = 3\nvalue = 23.1'),
#  Text(0.37251229220323107, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 23.2'),
#  Text(0.3762584874736596, 0.225, 'X[10] <= 17.4\nsquared_error = 0.003\nsamples = 2\nvalue = 23.05'),
#  Text(0.3743853898384453, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.3781315851088738, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.3762584874736596, 0.375, 'X[12] <= 11.78\nsquared_error = 0.563\nsamples = 2\nvalue = 20.95'),
#  Text(0.3743853898384453, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 20.2'),
#  Text(0.3781315851088738, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.3931163661905877, 0.475, 'X[7] <= 3.616\nsquared_error = 1.918\nsamples = 10\nvalue = 19.97'),
#  Text(0.3893701709201592, 0.425, 'X[12] <= 11.69\nsquared_error = 1.524\nsamples = 8\nvalue = 20.388'),
#  Text(0.387497073284945, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.39124326855537345, 0.375, 'X[7] <= 2.746\nsquared_error = 0.627\nsamples = 7\nvalue = 20.014'),
#  Text(0.3893701709201592, 0.325, 'X[0] <= 0.176\nsquared_error = 0.179\nsamples = 6\nvalue = 19.733'),
#  Text(0.3856239756497307, 0.275, 'X[12] <= 13.21\nsquared_error = 0.06\nsamples = 3\nvalue = 20.1'),
#  Text(0.3837508780145165, 0.225, 'X[6] <= 93.55\nsquared_error = 0.022\nsamples = 2\nvalue = 19.95'),
#  Text(0.38187778037930226, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.3856239756497307, 0.175, 'squared_error = -0.0\nsamples = 1\nvalue = 19.8'),
#  Text(0.387497073284945, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 20.4'),
#  Text(0.3931163661905877, 0.275, 'X[12] <= 12.43\nsquared_error = 0.029\nsamples = 3\nvalue = 19.367'),
#  Text(0.39124326855537345, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.3949894638258019, 0.225, 'X[6] <= 93.15\nsquared_error = 0.003\nsamples = 2\nvalue = 19.25'),
#  Text(0.3931163661905877, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.3968625614610162, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.2'),
#  Text(0.3931163661905877, 0.325, 'squared_error = -0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.3968625614610162, 0.425, 'X[12] <= 11.53\nsquared_error = 0.01\nsamples = 2\nvalue = 18.3'),
#  Text(0.3949894638258019, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.2'),
#  Text(0.3987356590962304, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.4370756263170218, 0.775, 'X[9] <= 269.0\nsquared_error = 11.694\nsamples = 55\nvalue = 27.427'),
#  Text(0.40295012877546244, 0.725, 'X[10] <= 17.85\nsquared_error = 5.38\nsamples = 17\nvalue = 30.241'),
#  Text(0.39592601264340904, 0.675, 'X[11] <= 393.41\nsquared_error = 2.699\nsamples = 10\nvalue = 31.71'),
#  Text(0.39124326855537345, 0.625, 'X[11] <= 392.415\nsquared_error = 0.76\nsamples = 5\nvalue = 30.4'),
#  Text(0.387497073284945, 0.575, 'X[5] <= 6.666\nsquared_error = 0.222\nsamples = 3\nvalue = 29.767'),
#  Text(0.3856239756497307, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 29.1'),
#  Text(0.3893701709201592, 0.525, 'squared_error = -0.0\nsamples = 2\nvalue = 30.1'),
#  Text(0.3949894638258019, 0.575, 'X[4] <= 0.406\nsquared_error = 0.063\nsamples = 2\nvalue = 31.35'),
#  Text(0.3931163661905877, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 31.1'),
#  Text(0.3968625614610162, 0.525, 'squared_error = -0.0\nsamples = 1\nvalue = 31.6'),
#  Text(0.40060875673144464, 0.625, 'X[4] <= 0.445\nsquared_error = 1.206\nsamples = 5\nvalue = 33.02'),
#  Text(0.3987356590962304, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 35.1'),
#  Text(0.40248185436665884, 0.575, 'X[11] <= 395.175\nsquared_error = 0.155\nsamples = 4\nvalue = 32.5'),
#  Text(0.40060875673144464, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 33.1'),
#  Text(0.4043549520018731, 0.525, 'X[5] <= 6.806\nsquared_error = 0.047\nsamples = 3\nvalue = 32.3'),
#  Text(0.40248185436665884, 0.475, 'X[8] <= 3.5\nsquared_error = 0.002\nsamples = 2\nvalue = 32.45'),
#  Text(0.40060875673144464, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 32.5'),
#  Text(0.4043549520018731, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 32.4'),
#  Text(0.4062280496370873, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.40997424490751583, 0.675, 'X[9] <= 249.5\nsquared_error = 1.725\nsamples = 7\nvalue = 28.143'),
#  Text(0.40810114727230157, 0.625, 'X[11] <= 392.83\nsquared_error = 0.64\nsamples = 6\nvalue = 27.7'),
#  Text(0.4062280496370873, 0.575, 'squared_error = 0.0\nsamples = 2\nvalue = 26.6'),
#  Text(0.40997424490751583, 0.575, 'X[6] <= 25.65\nsquared_error = 0.053\nsamples = 4\nvalue = 28.25'),
#  Text(0.40810114727230157, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.41184734254273003, 0.525, 'X[6] <= 64.2\nsquared_error = 0.016\nsamples = 3\nvalue = 28.367'),
#  Text(0.40997424490751583, 0.475, 'X[1] <= 56.5\nsquared_error = 0.003\nsamples = 2\nvalue = 28.45'),
#  Text(0.40810114727230157, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.41184734254273003, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 28.5'),
#  Text(0.4137204401779443, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 28.2'),
#  Text(0.41184734254273003, 0.625, 'squared_error = -0.0\nsamples = 1\nvalue = 30.8'),
#  Text(0.47120112385858115, 0.725, 'X[4] <= 0.526\nsquared_error = 9.392\nsamples = 38\nvalue = 26.168'),
#  Text(0.449075158042613, 0.675, 'X[4] <= 0.436\nsquared_error = 8.024\nsamples = 29\nvalue = 27.007'),
#  Text(0.4296417700772653, 0.625, 'X[6] <= 35.2\nsquared_error = 3.104\nsamples = 11\nvalue = 24.564'),
#  Text(0.42308592835401543, 0.575, 'X[10] <= 18.0\nsquared_error = 1.618\nsamples = 5\nvalue = 26.02'),
#  Text(0.41933973308358696, 0.525, 'X[5] <= 6.6\nsquared_error = 0.023\nsamples = 2\nvalue = 24.65'),
#  Text(0.41746663544837276, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.4212128307188012, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.42683212362444395, 0.525, 'X[4] <= 0.427\nsquared_error = 0.596\nsamples = 3\nvalue = 26.933'),
#  Text(0.4249590259892297, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 28.0'),
#  Text(0.42870522125965815, 0.475, 'X[0] <= 0.11\nsquared_error = 0.04\nsamples = 2\nvalue = 26.4'),
#  Text(0.42683212362444395, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.4305783188948724, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 26.2'),
#  Text(0.4361976118005151, 0.575, 'X[12] <= 8.435\nsquared_error = 1.103\nsamples = 6\nvalue = 23.35'),
#  Text(0.4343245141653009, 0.525, 'X[0] <= 0.044\nsquared_error = 0.287\nsamples = 4\nvalue = 24.025'),
#  Text(0.4324514165300866, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.4361976118005151, 0.475, 'X[10] <= 17.45\nsquared_error = 0.116\nsamples = 3\nvalue = 23.767'),
#  Text(0.4343245141653009, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.43807070943572934, 0.425, 'X[5] <= 6.599\nsquared_error = 0.01\nsamples = 2\nvalue = 24.0'),
#  Text(0.4361976118005151, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 24.1'),
#  Text(0.43994380707094355, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.43807070943572934, 0.525, 'squared_error = -0.0\nsamples = 2\nvalue = 22.0'),
#  Text(0.46850854600796066, 0.625, 'X[12] <= 7.05\nsquared_error = 5.153\nsamples = 18\nvalue = 28.5'),
#  Text(0.45492858815265746, 0.575, 'X[9] <= 301.5\nsquared_error = 1.409\nsamples = 9\nvalue = 30.144'),
#  Text(0.44743619761180053, 0.525, 'X[8] <= 4.5\nsquared_error = 0.367\nsamples = 4\nvalue = 29.075'),
#  Text(0.44369000234137207, 0.475, 'X[7] <= 4.728\nsquared_error = 0.01\nsamples = 2\nvalue = 28.5'),
#  Text(0.4418169047061578, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.4455630999765863, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 28.6'),
#  Text(0.451182392882229, 0.475, 'X[5] <= 6.703\nsquared_error = 0.062\nsamples = 2\nvalue = 29.65'),
#  Text(0.44930929524701474, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 29.4'),
#  Text(0.4530554905174432, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 29.9'),
#  Text(0.4624209786935144, 0.525, 'X[7] <= 4.178\nsquared_error = 0.596\nsamples = 5\nvalue = 31.0'),
#  Text(0.45867478342308593, 0.475, 'X[11] <= 387.105\nsquared_error = 0.062\nsamples = 2\nvalue = 31.75'),
#  Text(0.45680168578787167, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.4605478810583002, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.46616717396394286, 0.475, 'X[7] <= 5.516\nsquared_error = 0.327\nsamples = 3\nvalue = 30.5'),
#  Text(0.46429407632872866, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 29.8'),
#  Text(0.4680402715991571, 0.425, 'X[5] <= 6.806\nsquared_error = 0.122\nsamples = 2\nvalue = 30.85'),
#  Text(0.46616717396394286, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 30.5'),
#  Text(0.4699133692343713, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 31.2'),
#  Text(0.48208850386326385, 0.575, 'X[7] <= 3.9\nsquared_error = 3.489\nsamples = 9\nvalue = 26.856'),
#  Text(0.4774057597752283, 0.525, 'X[5] <= 6.727\nsquared_error = 1.618\nsamples = 5\nvalue = 28.12'),
#  Text(0.4736595645047998, 0.475, 'X[0] <= 0.531\nsquared_error = 0.303\nsamples = 2\nvalue = 29.55'),
#  Text(0.4717864668695856, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 29.0'),
#  Text(0.47553266214001405, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 30.1'),
#  Text(0.4811519550456568, 0.475, 'X[11] <= 395.17\nsquared_error = 0.222\nsamples = 3\nvalue = 27.167'),
#  Text(0.4792788574104425, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 27.5'),
#  Text(0.483025052680871, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 26.5'),
#  Text(0.48677124795129945, 0.525, 'X[10] <= 16.7\nsquared_error = 1.332\nsamples = 4\nvalue = 25.275'),
#  Text(0.48489815031608524, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 27.1'),
#  Text(0.4886443455865137, 0.475, 'X[1] <= 40.0\nsquared_error = 0.296\nsamples = 3\nvalue = 24.667'),
#  Text(0.48677124795129945, 0.425, 'X[6] <= 59.95\nsquared_error = 0.003\nsamples = 2\nvalue = 25.05'),
#  Text(0.48489815031608524, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.4886443455865137, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 25.1'),
#  Text(0.4905174432217279, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.4933270896745493, 0.675, 'X[10] <= 17.1\nsquared_error = 4.233\nsamples = 9\nvalue = 23.467'),
#  Text(0.4877077967689066, 0.625, 'X[11] <= 394.84\nsquared_error = 5.522\nsamples = 2\nvalue = 26.35'),
#  Text(0.4858346991336923, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 28.7'),
#  Text(0.48958089440412084, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 24.0'),
#  Text(0.49894638258019197, 0.625, 'X[10] <= 20.6\nsquared_error = 0.811\nsamples = 7\nvalue = 22.643'),
#  Text(0.4933270896745493, 0.575, 'X[7] <= 3.325\nsquared_error = 0.227\nsamples = 4\nvalue = 23.275'),
#  Text(0.49145399203933504, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 22.8'),
#  Text(0.4952001873097635, 0.525, 'X[9] <= 485.0\nsquared_error = 0.003\nsamples = 2\nvalue = 23.75'),
#  Text(0.4933270896745493, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.49707328494497777, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 23.7'),
#  Text(0.5045656754858348, 0.575, 'X[9] <= 290.0\nsquared_error = 0.347\nsamples = 3\nvalue = 21.8'),
#  Text(0.5026925778506205, 0.525, 'X[12] <= 8.075\nsquared_error = 0.04\nsamples = 2\nvalue = 22.2'),
#  Text(0.5008194802154062, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.5045656754858348, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 22.4'),
#  Text(0.5064387731210489, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.6656959728400843, 0.875, 'X[0] <= 6.992\nsquared_error = 19.276\nsamples = 175\nvalue = 14.956'),
#  Text(0.5885623975649731, 0.825, 'X[4] <= 0.531\nsquared_error = 11.391\nsamples = 101\nvalue = 17.138'),
#  Text(0.5338328260360571, 0.775, 'X[7] <= 5.57\nsquared_error = 9.016\nsamples = 24\nvalue = 20.021'),
#  Text(0.5214235542027629, 0.725, 'X[6] <= 88.55\nsquared_error = 2.862\nsamples = 13\nvalue = 21.454'),
#  Text(0.5139311636619058, 0.675, 'X[11] <= 385.375\nsquared_error = 0.792\nsamples = 6\nvalue = 22.967'),
#  Text(0.5101849683914774, 0.625, 'X[0] <= 0.213\nsquared_error = 0.122\nsamples = 2\nvalue = 24.05'),
#  Text(0.5083118707562632, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.5120580660266917, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 23.7'),
#  Text(0.5176773589323344, 0.625, 'X[4] <= 0.517\nsquared_error = 0.247\nsamples = 4\nvalue = 22.425'),
#  Text(0.5158042612971201, 0.575, 'X[0] <= 0.178\nsquared_error = 0.096\nsamples = 3\nvalue = 22.667'),
#  Text(0.5139311636619058, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.5176773589323344, 0.525, 'X[11] <= 390.185\nsquared_error = 0.003\nsamples = 2\nvalue = 22.45'),
#  Text(0.5158042612971201, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.5195504565675486, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 22.4'),
#  Text(0.5195504565675486, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.5289159447436198, 0.675, 'X[5] <= 5.905\nsquared_error = 0.994\nsamples = 7\nvalue = 20.157'),
#  Text(0.5251697494731913, 0.625, 'X[0] <= 0.406\nsquared_error = 0.067\nsamples = 4\nvalue = 19.575'),
#  Text(0.523296651837977, 0.575, 'X[4] <= 0.504\nsquared_error = 0.009\nsamples = 3\nvalue = 19.433'),
#  Text(0.5214235542027629, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.5251697494731913, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 19.5'),
#  Text(0.5270428471084055, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(0.5326621400140482, 0.625, 'X[9] <= 345.5\nsquared_error = 1.176\nsamples = 3\nvalue = 20.933'),
#  Text(0.530789042378834, 0.575, 'squared_error = 0.0\nsamples = 2\nvalue = 21.7'),
#  Text(0.5345352376492625, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 19.4'),
#  Text(0.5462420978693514, 0.725, 'X[0] <= 0.157\nsquared_error = 10.993\nsamples = 11\nvalue = 18.327'),
#  Text(0.538281432919691, 0.675, 'X[10] <= 15.6\nsquared_error = 12.827\nsamples = 3\nvalue = 22.1'),
#  Text(0.5364083352844767, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 27.1'),
#  Text(0.5401545305549051, 0.625, 'X[7] <= 6.82\nsquared_error = 0.49\nsamples = 2\nvalue = 19.6'),
#  Text(0.538281432919691, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.5420276281901194, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 18.9'),
# ...
#  Text(0.8051978459377195, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 7.5'),
#  Text(0.808944041208148, 0.525, 'squared_error = -0.0\nsamples = 1\nvalue = 6.3'),
#  Text(0.8309529384219152, 0.625, 'X[7] <= 1.589\nsquared_error = 2.76\nsamples = 19\nvalue = 8.053'),
#  Text(0.817372980566612, 0.575, 'X[5] <= 4.826\nsquared_error = 3.204\nsamples = 8\nvalue = 7.088'),
#  Text(0.8126902364785764, 0.525, 'X[11] <= 341.365\nsquared_error = 0.722\nsamples = 2\nvalue = 9.65'),
#  Text(0.8108171388433623, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 8.8'),
#  Text(0.8145633341137907, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 10.5'),
#  Text(0.8220557246546476, 0.525, 'X[0] <= 23.822\nsquared_error = 1.112\nsamples = 6\nvalue = 6.233'),
#  Text(0.8183095293842192, 0.475, 'X[6] <= 93.8\nsquared_error = 0.009\nsamples = 3\nvalue = 7.267'),
#  Text(0.8164364317490049, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 7.4'),
#  Text(0.8201826270194333, 0.425, 'squared_error = -0.0\nsamples = 2\nvalue = 7.2'),
#  Text(0.8258019199250761, 0.475, 'X[5] <= 5.835\nsquared_error = 0.08\nsamples = 3\nvalue = 5.2'),
#  Text(0.8239288222898619, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.8276750175602904, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 5.6'),
#  Text(0.8445328962772185, 0.575, 'X[11] <= 107.815\nsquared_error = 1.268\nsamples = 11\nvalue = 8.755'),
#  Text(0.8389136033715757, 0.525, 'X[12] <= 27.75\nsquared_error = 0.499\nsamples = 6\nvalue = 8.067'),
#  Text(0.833294310465933, 0.475, 'X[5] <= 5.926\nsquared_error = 0.047\nsamples = 3\nvalue = 8.6'),
#  Text(0.8314212128307188, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 8.3'),
#  Text(0.8351674081011473, 0.425, 'X[7] <= 1.858\nsquared_error = 0.002\nsamples = 2\nvalue = 8.75'),
#  Text(0.833294310465933, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 8.8'),
#  Text(0.8370405057363615, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 8.7'),
#  Text(0.8445328962772185, 0.475, 'X[4] <= 0.717\nsquared_error = 0.382\nsamples = 3\nvalue = 7.533'),
#  Text(0.8426597986420042, 0.425, 'X[5] <= 5.477\nsquared_error = 0.01\nsamples = 2\nvalue = 7.1'),
#  Text(0.84078670100679, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.8445328962772185, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.2'),
#  Text(0.8464059939124327, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 8.4'),
#  Text(0.8501521891828612, 0.525, 'X[12] <= 20.94\nsquared_error = 0.942\nsamples = 5\nvalue = 9.58'),
#  Text(0.8482790915476469, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 8.3'),
#  Text(0.8520252868180754, 0.475, 'X[0] <= 33.735\nsquared_error = 0.665\nsamples = 4\nvalue = 9.9'),
#  Text(0.8501521891828612, 0.425, 'X[6] <= 96.2\nsquared_error = 0.016\nsamples = 3\nvalue = 10.367'),
#  Text(0.8482790915476469, 0.375, 'X[5] <= 5.561\nsquared_error = 0.003\nsamples = 2\nvalue = 10.45'),
#  Text(0.8464059939124327, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.8501521891828612, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 10.5'),
#  Text(0.8520252868180754, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 10.2'),
#  Text(0.8538983844532896, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 8.5'),
#  Text(0.9359781081713884, 0.925, 'X[5] <= 7.437\nsquared_error = 79.729\nsamples = 76\nvalue = 37.238'),
#  Text(0.9082474830250526, 0.875, 'X[4] <= 0.659\nsquared_error = 41.296\nsamples = 46\nvalue = 32.113'),
#  Text(0.889077499414657, 0.825, 'X[7] <= 1.886\nsquared_error = 20.111\nsamples = 43\nvalue = 33.349'),
#  Text(0.8756731444626551, 0.775, 'X[6] <= 97.45\nsquared_error = 18.923\nsamples = 2\nvalue = 45.65'),
#  Text(0.8738000468274408, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 41.3'),
#  Text(0.8775462420978694, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9024818543666588, 0.775, 'X[4] <= 0.488\nsquared_error = 12.427\nsamples = 41\nvalue = 32.749'),
#  Text(0.8812924373682979, 0.725, 'X[6] <= 11.95\nsquared_error = 5.014\nsamples = 27\nvalue = 34.156'),
#  Text(0.8730976352142356, 0.675, 'X[1] <= 46.0\nsquared_error = 0.09\nsamples = 2\nvalue = 29.3'),
#  Text(0.8712245375790213, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.8749707328494498, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 29.0'),
#  Text(0.8894872395223601, 0.675, 'X[12] <= 5.44\nsquared_error = 3.371\nsamples = 25\nvalue = 34.544'),
#  Text(0.8787169281198782, 0.625, 'X[0] <= 0.049\nsquared_error = 2.397\nsamples = 16\nvalue = 35.306'),
#  Text(0.8698197143526106, 0.575, 'X[12] <= 4.505\nsquared_error = 0.88\nsamples = 8\nvalue = 34.363'),
#  Text(0.8632638726293608, 0.525, 'X[2] <= 2.565\nsquared_error = 0.646\nsamples = 5\nvalue = 33.84'),
#  Text(0.8595176773589324, 0.475, 'X[9] <= 365.5\nsquared_error = 0.047\nsamples = 3\nvalue = 33.2'),
#  Text(0.8576445797237181, 0.425, 'X[7] <= 6.686\nsquared_error = 0.003\nsamples = 2\nvalue = 33.35'),
#  Text(0.8557714820885038, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 33.4'),
#  Text(0.8595176773589324, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 33.3'),
#  Text(0.8613907749941466, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 32.9'),
#  Text(0.8670100678997893, 0.475, 'X[11] <= 394.225\nsquared_error = 0.01\nsamples = 2\nvalue = 34.8'),
#  Text(0.865136970264575, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 34.7'),
#  Text(0.8688831655350036, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 34.9'),
#  Text(0.8763755560758605, 0.525, 'X[11] <= 396.415\nsquared_error = 0.056\nsamples = 3\nvalue = 35.233'),
#  Text(0.8745024584406462, 0.475, 'X[1] <= 55.0\nsquared_error = 0.0\nsamples = 2\nvalue = 35.4'),
#  Text(0.872629360805432, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 35.4'),
#  Text(0.8763755560758605, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 35.4'),
#  Text(0.8782486537110747, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 34.9'),
#  Text(0.8876141418871458, 0.575, 'X[2] <= 5.52\nsquared_error = 2.133\nsamples = 8\nvalue = 36.25'),
#  Text(0.8857410442519317, 0.525, 'X[12] <= 5.36\nsquared_error = 0.817\nsamples = 7\nvalue = 36.7'),
#  Text(0.8838679466167174, 0.475, 'X[7] <= 5.589\nsquared_error = 0.323\nsamples = 6\nvalue = 37.0'),
#  Text(0.8801217513462889, 0.425, 'X[6] <= 75.3\nsquared_error = 0.096\nsamples = 3\nvalue = 37.467'),
#  Text(0.8782486537110747, 0.375, 'X[8] <= 3.5\nsquared_error = 0.003\nsamples = 2\nvalue = 37.25'),
#  Text(0.8763755560758605, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 37.2'),
#  Text(0.8801217513462889, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 37.3'),
#  Text(0.8819948489815032, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 37.9'),
#  Text(0.8876141418871458, 0.425, 'X[0] <= 0.089\nsquared_error = 0.116\nsamples = 3\nvalue = 36.533'),
#  Text(0.8857410442519317, 0.375, 'X[4] <= 0.448\nsquared_error = 0.01\nsamples = 2\nvalue = 36.3'),
#  Text(0.8838679466167174, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 36.4'),
#  Text(0.8876141418871458, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 36.2'),
#  Text(0.8894872395223601, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 37.0'),
#  Text(0.8876141418871458, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 34.9'),
#  Text(0.8894872395223601, 0.525, 'squared_error = -0.0\nsamples = 1\nvalue = 33.1'),
#  Text(0.9002575509248419, 0.625, 'X[6] <= 37.45\nsquared_error = 2.234\nsamples = 9\nvalue = 33.189'),
#  Text(0.8951065324280028, 0.575, 'X[11] <= 374.515\nsquared_error = 0.903\nsamples = 2\nvalue = 31.25'),
#  Text(0.8932334347927886, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 30.3'),
#  Text(0.896979630063217, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 32.2'),
#  Text(0.9054085694216811, 0.575, 'X[6] <= 45.05\nsquared_error = 1.234\nsamples = 7\nvalue = 33.743'),
#  Text(0.9007258253336455, 0.525, 'X[12] <= 6.775\nsquared_error = 0.562\nsamples = 2\nvalue = 35.35'),
#  Text(0.8988527276984313, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 34.6'),
#  Text(0.9025989229688598, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 36.1'),
#  Text(0.9100913135097167, 0.525, 'X[5] <= 7.254\nsquared_error = 0.056\nsamples = 5\nvalue = 33.1'),
#  Text(0.9063451182392882, 0.475, 'X[9] <= 250.0\nsquared_error = 0.022\nsamples = 2\nvalue = 32.85'),
#  Text(0.904472020604074, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 33.0'),
#  Text(0.9082182158745025, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 32.7'),
#  Text(0.9138375087801451, 0.475, 'X[10] <= 18.2\nsquared_error = 0.009\nsamples = 3\nvalue = 33.267'),
#  Text(0.9119644111449309, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 33.2'),
#  Text(0.9157106064153594, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 33.4'),
#  Text(0.9236712713650199, 0.725, 'X[5] <= 7.121\nsquared_error = 15.547\nsamples = 14\nvalue = 30.036'),
#  Text(0.9157106064153594, 0.675, 'X[11] <= 387.885\nsquared_error = 7.09\nsamples = 7\nvalue = 26.914'),
#  Text(0.9119644111449309, 0.625, 'X[7] <= 2.333\nsquared_error = 0.203\nsamples = 2\nvalue = 30.25'),
#  Text(0.9100913135097167, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 30.7'),
#  Text(0.9138375087801451, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 29.8'),
#  Text(0.9194568016857879, 0.625, 'X[6] <= 70.05\nsquared_error = 3.614\nsamples = 5\nvalue = 25.58'),
#  Text(0.9175837040505737, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 28.7'),
#  Text(0.9213298993210021, 0.575, 'X[5] <= 6.964\nsquared_error = 1.475\nsamples = 4\nvalue = 24.8'),
#  Text(0.9194568016857879, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 26.7'),
#  Text(0.9232029969562163, 0.525, 'X[5] <= 7.034\nsquared_error = 0.362\nsamples = 3\nvalue = 24.167'),
#  Text(0.9213298993210021, 0.475, 'X[7] <= 2.795\nsquared_error = 0.023\nsamples = 2\nvalue = 23.75'),
#  Text(0.9194568016857879, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.9232029969562163, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.9250760945914306, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.9316319363146804, 0.675, 'X[7] <= 2.004\nsquared_error = 4.517\nsamples = 7\nvalue = 33.157'),
#  Text(0.9269491922266448, 0.625, 'X[6] <= 95.8\nsquared_error = 0.062\nsamples = 2\nvalue = 36.25'),
#  Text(0.9250760945914306, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 36.5'),
#  Text(0.928822289861859, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 36.0'),
#  Text(0.936314680402716, 0.625, 'X[5] <= 7.265\nsquared_error = 0.942\nsamples = 5\nvalue = 31.92'),
#  Text(0.9325684851322875, 0.575, 'X[11] <= 382.44\nsquared_error = 1.21\nsamples = 2\nvalue = 32.7'),
#  Text(0.9306953874970733, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 31.6'),
#  Text(0.9344415827675018, 0.525, 'squared_error = -0.0\nsamples = 1\nvalue = 33.8'),
#  Text(0.9400608756731444, 0.575, 'X[5] <= 7.342\nsquared_error = 0.087\nsamples = 3\nvalue = 31.4'),
#  Text(0.9381877780379302, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 31.0'),
#  Text(0.9419339733083587, 0.525, 'X[12] <= 4.99\nsquared_error = 0.01\nsamples = 2\nvalue = 31.6'),
#  Text(0.9400608756731444, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.943807070943573, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 31.7'),
#  Text(0.9274174666354483, 0.825, 'X[5] <= 7.141\nsquared_error = 9.307\nsamples = 3\nvalue = 14.4'),
#  Text(0.9255443690002342, 0.775, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.9292905642706626, 0.775, 'X[12] <= 15.09\nsquared_error = 1.96\nsamples = 2\nvalue = 16.4'),
#  Text(0.9274174666354483, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.9311636619058768, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 17.8'),
#  Text(0.9637087333177242, 0.875, 'X[0] <= 2.742\nsquared_error = 36.628\nsamples = 30\nvalue = 45.097'),
#  Text(0.96183563568251, 0.825, 'X[10] <= 14.8\nsquared_error = 18.697\nsamples = 29\nvalue = 45.897'),
#  Text(0.9494263638492156, 0.775, 'X[5] <= 7.706\nsquared_error = 8.027\nsamples = 14\nvalue = 48.3'),
#  Text(0.9456801685787871, 0.725, 'X[7] <= 2.055\nsquared_error = 9.462\nsamples = 4\nvalue = 44.725'),
#  Text(0.943807070943573, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9475532662140014, 0.675, 'X[10] <= 13.85\nsquared_error = 0.249\nsamples = 3\nvalue = 42.967'),
#  Text(0.9456801685787871, 0.625, 'X[12] <= 5.21\nsquared_error = 0.04\nsamples = 2\nvalue = 43.3'),
#  Text(0.943807070943573, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 43.5'),
#  Text(0.9475532662140014, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 43.1'),
#  Text(0.9494263638492156, 0.625, 'squared_error = -0.0\nsamples = 1\nvalue = 42.3'),
#  Text(0.9531725591196442, 0.725, 'X[12] <= 3.755\nsquared_error = 0.296\nsamples = 10\nvalue = 49.73'),
#  Text(0.9512994614844299, 0.675, 'squared_error = 0.0\nsamples = 6\nvalue = 50.0'),
#  Text(0.9550456567548583, 0.675, 'X[0] <= 0.549\nsquared_error = 0.467\nsamples = 4\nvalue = 49.325'),
#  Text(0.9531725591196442, 0.625, 'X[12] <= 4.86\nsquared_error = 0.023\nsamples = 2\nvalue = 48.65'),
#  Text(0.9512994614844299, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 48.5'),
#  Text(0.9550456567548583, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 48.8'),
#  Text(0.9569187543900726, 0.625, 'squared_error = -0.0\nsamples = 2\nvalue = 50.0'),
#  Text(0.9742449075158043, 0.775, 'X[11] <= 385.48\nsquared_error = 18.232\nsamples = 15\nvalue = 43.653'),
#  Text(0.9662842425661438, 0.725, 'X[0] <= 0.323\nsquared_error = 3.298\nsamples = 5\nvalue = 47.16'),
#  Text(0.9625380472957152, 0.675, 'X[0] <= 0.307\nsquared_error = 0.616\nsamples = 3\nvalue = 45.833'),
#  Text(0.9606649496605011, 0.625, 'X[8] <= 6.5\nsquared_error = 0.122\nsamples = 2\nvalue = 46.35'),
#  Text(0.9587918520252868, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 46.0'),
#  Text(0.9625380472957152, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 46.7'),
#  Text(0.9644111449309295, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 44.8'),
#  Text(0.9700304378365723, 0.675, 'X[7] <= 3.273\nsquared_error = 0.722\nsamples = 2\nvalue = 49.15'),
#  Text(0.968157340201358, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9719035354717864, 0.625, 'squared_error = -0.0\nsamples = 1\nvalue = 48.3'),
#  Text(0.9822055724654648, 0.725, 'X[0] <= 0.061\nsquared_error = 16.476\nsamples = 10\nvalue = 41.9'),
#  Text(0.9775228283774292, 0.675, 'X[0] <= 0.046\nsquared_error = 6.569\nsamples = 3\nvalue = 46.467'),
#  Text(0.975649730742215, 0.625, 'X[10] <= 15.4\nsquared_error = 0.49\nsamples = 2\nvalue = 44.7'),
#  Text(0.9737766331070007, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 45.4'),
#  Text(0.9775228283774292, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 44.0'),
#  Text(0.9793959260126434, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9868883165535004, 0.675, 'X[6] <= 44.35\nsquared_error = 7.954\nsamples = 7\nvalue = 39.943'),
#  Text(0.9831421212830719, 0.625, 'X[10] <= 18.55\nsquared_error = 0.25\nsamples = 2\nvalue = 43.3'),
#  Text(0.9812690236478576, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 43.8'),
#  Text(0.9850152189182861, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 42.8'),
#  Text(0.9906345118239288, 0.625, 'X[6] <= 62.55\nsquared_error = 4.724\nsamples = 5\nvalue = 38.6'),
#  Text(0.9887614141887145, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 35.2'),
#  Text(0.9925076094591431, 0.575, 'X[11] <= 386.645\nsquared_error = 2.293\nsamples = 4\nvalue = 39.45'),
#  Text(0.9906345118239288, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 41.7'),
#  Text(0.9943807070943573, 0.525, 'X[0] <= 0.093\nsquared_error = 0.807\nsamples = 3\nvalue = 38.7'),
#  Text(0.9925076094591431, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 39.8'),
#  Text(0.9962538047295715, 0.475, 'X[8] <= 5.0\nsquared_error = 0.303\nsamples = 2\nvalue = 38.15'),
#  Text(0.9943807070943573, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 38.7'),
#  Text(0.9981269023647857, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 37.6'),
#  Text(0.9655818309529384, 0.825, 'squared_error = -0.0\nsamples = 1\nvalue = 21.9')]

# %% [markdown]
# ##### graphviz를 사용한 시각화

# %%
dot_data = tree.export_graphviz(decision_tree=model,
                               feature_names=boston.feature_names,
                               filled=True, rounded=True,
                               special_characters=True)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# #### 시각화

# %% [markdown]
# ##### 회귀식 시각화

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([0,1,2]):
    X = boston.data[:,pair].reshape(-1,1)
    y = boston.target
    
    model = DecisionTreeRegressor()
    model.fit(X,y)
    
    X_test = np.arange(min(X), max(X), 0.1)[:, np.newaxis]
    predict = model.predict(X_test)
    
    plt.subplot(1,3, pairidx + 1)
    plt.scatter(X,y, s=20, edgecolors='k',
               c='darkorange', label='data')
    plt.plot(X_test, predict, color = 'royalblue', linewidth=2)
    plt.xlabel(boston.feature_names[pair])
    plt.ylabel('target')

# %% [markdown]
# ##### 하이퍼파리미터를 변경해 보면서 회귀식 시각화

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([0,1,2]):
    X = boston.data[:,pair].reshape(-1,1)
    y = boston.target
    
    model = DecisionTreeRegressor(max_depth=3)
    model.fit(X,y)
    
    X_test = np.arange(min(X), max(X), 0.1)[:, np.newaxis]
    predict = model.predict(X_test)
    
    plt.subplot(1,3, pairidx + 1)
    plt.scatter(X,y, s=20, edgecolors='k',
               c='darkorange', label='data')
    plt.plot(X_test, predict, color = 'royalblue', linewidth=2)
    plt.xlabel(boston.feature_names[pair])
    plt.ylabel('target')

# %% [markdown]
# ### 당뇨병 데이터 학습

# %% [markdown]
# #### 교차검증

# %% [markdown]
# ##### 전처리 없이 학습

# %% [markdown]
# ##### 전처리 후 학습
# * 결정 트리는 규칙을 학습하기 때문에 전처리에 큰 영향을 받지 않는다.

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %% [markdown]
# ##### 텍스트를 통한 시각화

# %% [markdown]
# ##### plot_tree를 사용한 시각화

# %% [markdown]
# ##### graphviz를 사용한 시각화

# %% [markdown]
# #### 시각화

# %% [markdown]
# ##### 회귀식 시각화

# %% [markdown]
# ##### 하이퍼파리미터를 변경해 보면서 회귀식 시각화
